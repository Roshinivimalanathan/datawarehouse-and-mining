# %%
pip install pyfpgrowth
# Out:
# Collecting pyfpgrowth
#   Using cached pyfpgrowth-1.0.tar.gz (1.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py): started
#   Building wheel for pyfpgrowth (setup.py): finished with status 'done'
#   Created wheel for pyfpgrowth: filename=pyfpgrowth-1.0-py2.py3-none-any.whl size=5510 sha256=174b2d936d0a7bd0b6adb2551db3fd5255d3a1d491957c97a3157f8ba0b75f89
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\09\fc\dc\afff211038bfc745722d8d7e846e854e5791968b22c570a530
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wheel setuptools pip --upgrade
# Out:
# Requirement already satisfied: wheel in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (0.41.2)
# Requirement already satisfied: setuptools in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (68.2.2)
# Requirement already satisfied: pip in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (23.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyfpgrowth

# %%
pip install pip==23.2.1
# Out:
# Requirement already satisfied: pip==23.2.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (23.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('dataset.csv')

# %%
patterns=pyfpgrowth.find_frequent_patterns(df,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 patterns=pyfpgrowth.find_frequent_patterns(df,min_support=2)
#
# TypeError: find_frequent_patterns() got an unexpected keyword argument 'min_support'

# %%
patterns
# Out:
# {(' ', 'n', 'x'): 2,
#  (' ', 'i', 'n', 'x'): 4,
#  (' ', 'n', 't', 'x'): 4,
#  (' ', 'a', 'n', 'x'): 4,
#  (' ', 'e', 'n', 'x'): 2,
#  (' ', 'i', 'n', 't', 'x'): 4,
#  (' ', 'a', 'i', 'n', 'x'): 4,
#  (' ', 'e', 'i', 'n', 'x'): 2,
#  (' ', 'a', 'n', 't', 'x'): 4,
#  (' ', 'e', 'n', 't', 'x'): 2,
#  (' ', 'a', 'e', 'n', 'x'): 2,
#  (' ', 'a', 'i', 'n', 't', 'x'): 4,
#  (' ', 'e', 'i', 'n', 't', 'x'): 2,
#  (' ', 'a', 'e', 'i', 'n', 'x'): 2,
#  (' ', 'a', 'e', 'n', 't', 'x'): 2,
#  (' ', 'a', 'e', 'i', 'n', 't', 'x'): 2,
#  (' ', 'a', 'x'): 3,
#  (' ', 'a', 'e', 'x'): 5,
#  (' ', 'a', 't', 'x'): 5,
#  (' ', 'a', 'a', 't', 'x'): 2,
#  (' ', 'e', 'e', 't', 'x'): 3,
#  (' ', 'a', 'e', 'e', 't', 'x'): 3,
#  (' ', 'a', 'e', 't', 'x'): 7,
#  (' ', 'a', 'a', 'e', 't', 'x'): 2,
#  (' ', 'i', 't', 'x'): 5,
#  (' ', 'i', 't', 't', 'x'): 2,
#  (' ', 'a', 'i', 'x'): 5,
#  (' ', 'a', 'i', 't', 'x'): 9,
#  (' ', 'a', 'a', 'i', 'x'): 2,
#  (' ', 'a', 'a', 'i', 't', 'x'): 2,
#  (' ', 'e', 'e', 'i', 'x'): 3,
#  (' ', 'e', 'e', 'i', 't', 'x'): 3,
#  (' ', 'a', 'e', 'e', 'i', 'x'): 3,
#  (' ', 'a', 'e', 'e', 'i', 't', 'x'): 3,
#  (' ', 'a', 'e', 'i', 'x'): 7,
#  (' ', 'a', 'a', 'e', 'i', 'x'): 2,
#  (' ', 'e', 'i', 't', 'x'): 7,
#  (' ', 'a', 'e', 'i', 't', 'x'): 11,
#  (' ', 'e', 'i', 't', 't', 'x'): 2,
#  (' ', 'a', 'e', 'i', 't', 't', 'x'): 2,
#  (' ', 'e', 'x'): 4,
#  (' ', 'e', 'e', 'x'): 3,
#  ('n', 'x'): 2,
#  ('a', 'n', 'x'): 4,
#  ('n', 't', 'x'): 4,
#  ('i', 'n', 'x'): 4,
#  ('e', 'n', 'x'): 2,
#  ('a', 'n', 't', 'x'): 4,
#  ('a', 'i', 'n', 'x'): 4,
#  ('a', 'e', 'n', 'x'): 2,
#  ('i', 'n', 't', 'x'): 4,
#  ('e', 'n', 't', 'x'): 2,
#  ('e', 'i', 'n', 'x'): 2,
#  ('a', 'i', 'n', 't', 'x'): 4,
#  ('a', 'e', 'n', 't', 'x'): 2,
#  ('a', 'e', 'i', 'n', 'x'): 2,
#  ('e', 'i', 'n', 't', 'x'): 2,
#  ('a', 'e', 'i', 'n', 't', 'x'): 2,
#  ('i', 'x'): 3,
#  ('e', 'i', 'x'): 5,
#  ('i', 't', 'x'): 5,
#  ('i', 'i', 't', 'x'): 2,
#  ('e', 'e', 't', 'x'): 3,
#  ('e', 'e', 'i', 't', 'x'): 3,
#  ('e', 'i', 't', 'x'): 7,
#  ('e', 'i', 'i', 't', 'x'): 2,
#  ('a', 't', 'x'): 5,
#  ('a', 't', 't', 'x'): 2,
#  ('a', 'i', 'x'): 5,
#  ('a', 'i', 't', 'x'): 9,
#  ('a', 'i', 'i', 'x'): 2,
#  ('a', 'i', 'i', 't', 'x'): 2,
#  ('a', 'e', 'e', 'x'): 3,
#  ('a', 'e', 'e', 't', 'x'): 3,
#  ('a', 'e', 'e', 'i', 'x'): 3,
#  ('a', 'e', 'e', 'i', 't', 'x'): 3,
#  ('a', 'e', 'i', 'x'): 7,
#  ('a', 'e', 'i', 'i', 'x'): 2,
#  ('a', 'e', 't', 'x'): 7,
#  ('a', 'e', 'i', 't', 'x'): 11,
#  ('a', 'e', 't', 't', 'x'): 2,
#  ('a', 'e', 'i', 't', 't', 'x'): 2,
#  ('e', 'x'): 4,
#  ('e', 'e', 'x'): 3,
#  ('a', 'j', 'u'): 3,
#  ('a', 'j', 't', 'u'): 6,
#  ('j', 'o', 'u'): 3,
#  ('a', 'j', 'o', 'u'): 4,
#  ('j', 'o', 't', 'u'): 6,
#  ('a', 'j', 'o', 't', 'u'): 4,
#  ('i', 'j', 'o', 'u'): 4,
#  ('a', 'i', 'j', 'o', 'u'): 6,
#  ('i', 'j', 'o', 't', 'u'): 8,
#  ('a', 'i', 'j', 'o', 't', 'u'): 6,
#  ('a', 'i', 'j', 'u'): 5,
#  ('a', 'i', 'j', 't', 'u'): 10,
#  ('a', 'a', 'i', 'j', 'u'): 2,
#  ('a', 'a', 'i', 'j', 't', 'u'): 2,
#  ('i', 'j', 't', 'u'): 6,
#  ('i', 'j', 't', 't', 'u'): 3,
#  ('j', 't', 'u'): 4,
#  ('j', 't', 't', 'u'): 2,
#  ('c', 'i', 'j', 'u'): 3,
#  ('c', 'i', 'j', 't', 'u'): 6,
#  ('c', 'j', 'o', 'u'): 3,
#  ('c', 'i', 'j', 'o', 'u'): 4,
#  ('c', 'j', 'o', 't', 'u'): 6,
#  ('c', 'i', 'j', 'o', 't', 'u'): 4,
#  ('a', 'c', 'j', 'o', 'u'): 4,
#  ('a', 'c', 'i', 'j', 'o', 'u'): 6,
#  ('a', 'c', 'j', 'o', 't', 'u'): 8,
#  ('a', 'c', 'i', 'j', 'o', 't', 'u'): 6,
#  ('a', 'c', 'i', 'j', 'u'): 5,
#  ('a', 'c', 'i', 'j', 't', 'u'): 10,
#  ('a', 'c', 'i', 'i', 'j', 'u'): 2,
#  ('a', 'c', 'i', 'i', 'j', 't', 'u'): 2,
#  ('a', 'c', 'j', 't', 'u'): 6,
#  ('a', 'c', 'j', 't', 't', 'u'): 3,
#  ('c', 'j', 't', 'u'): 4,
#  ('c', 'j', 't', 't', 'u'): 2,
#  ('a', 'c', 'j'): 3,
#  ('a', 'c', 'j', 't'): 6,
#  ('c', 'j', 'o'): 3,
#  ('a', 'c', 'j', 'o'): 4,
#  ('c', 'j', 'o', 't'): 6,
#  ('a', 'c', 'j', 'o', 't'): 4,
#  ('c', 'i', 'j', 'o'): 4,
#  ('a', 'c', 'i', 'j', 'o'): 6,
#  ('c', 'i', 'j', 'o', 't'): 8,
#  ('a', 'c', 'i', 'j', 'o', 't'): 6,
#  ('a', 'c', 'i', 'j'): 5,
#  ('a', 'c', 'i', 'j', 't'): 10,
#  ('a', 'a', 'c', 'i', 'j'): 2,
#  ('a', 'a', 'c', 'i', 'j', 't'): 2,
#  ('c', 'i', 'j', 't'): 6,
#  ('c', 'i', 'j', 't', 't'): 3,
#  ('c', 'j', 't'): 4,
#  ('c', 'j', 't', 't'): 2,
#  (' ', 'c', 'j', 'n'): 2,
#  (' ', 'a', 'c', 'j', 'n'): 4,
#  (' ', 'c', 'j', 'n', 'o'): 2,
#  (' ', 'c', 'i', 'j', 'n'): 4,
#  (' ', 'c', 'j', 'n', 't'): 4,
#  (' ', 'a', 'c', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n'): 4,
#  (' ', 'a', 'c', 'j', 'n', 't'): 4,
#  (' ', 'c', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'c', 'j', 'n', 'o', 't'): 2,
#  (' ', 'c', 'i', 'j', 'n', 't'): 4,
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'c', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 't'): 4,
#  (' ', 'c', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'c', 'i', 'j'): 3,
#  (' ', 'c', 'i', 'j', 't'): 6,
#  (' ', 'c', 'j', 'o'): 3,
#  (' ', 'c', 'i', 'j', 'o'): 4,
#  (' ', 'c', 'j', 'o', 't'): 6,
#  (' ', 'c', 'i', 'j', 'o', 't'): 4,
#  (' ', 'a', 'c', 'j', 'o'): 4,
#  (' ', 'a', 'c', 'i', 'j', 'o'): 6,
#  (' ', 'a', 'c', 'j', 'o', 't'): 8,
#  (' ', 'a', 'c', 'i', 'j', 'o', 't'): 6,
#  (' ', 'a', 'c', 'i', 'j'): 5,
#  (' ', 'a', 'c', 'i', 'j', 't'): 10,
#  (' ', 'a', 'c', 'i', 'i', 'j'): 2,
#  (' ', 'a', 'c', 'i', 'i', 'j', 't'): 2,
#  (' ', 'a', 'c', 'j', 't'): 6,
#  (' ', 'a', 'c', 'j', 't', 't'): 3,
#  (' ', 'c', 'j', 't'): 4,
#  (' ', 'c', 'j', 't', 't'): 2,
#  (' ', 'a', 'c', 'j', 'u'): 3,
#  (' ', 'a', 'c', 'j', 't', 'u'): 6,
#  (' ', 'c', 'j', 'o', 'u'): 3,
#  (' ', 'a', 'c', 'j', 'o', 'u'): 4,
#  (' ', 'c', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'c', 'j', 'o', 't', 'u'): 4,
#  (' ', 'c', 'i', 'j', 'o', 'u'): 4,
#  (' ', 'a', 'c', 'i', 'j', 'o', 'u'): 6,
#  (' ', 'c', 'i', 'j', 'o', 't', 'u'): 8,
#  (' ', 'a', 'c', 'i', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'c', 'i', 'j', 'u'): 5,
#  (' ', 'a', 'c', 'i', 'j', 't', 'u'): 10,
#  (' ', 'a', 'a', 'c', 'i', 'j', 'u'): 2,
#  (' ', 'a', 'a', 'c', 'i', 'j', 't', 'u'): 2,
#  (' ', 'c', 'i', 'j', 't', 'u'): 6,
#  (' ', 'c', 'i', 'j', 't', 't', 'u'): 3,
#  (' ', 'c', 'j', 't', 'u'): 4,
#  (' ', 'c', 'j', 't', 't', 'u'): 2,
#  (' ', 'j', 'n', 'u'): 2,
#  (' ', 'c', 'j', 'n', 'u'): 2,
#  (' ', 'a', 'j', 'n', 'u'): 4,
#  (' ', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'c', 'j', 'n', 'u'): 2,
#  (' ', 'c', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'c', 'i', 'j', 'n', 'u'): 2,
#  (' ', 'c', 'j', 'n', 't', 'u'): 2,
#  (' ', 'a', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'a', 'j', 'n', 't', 'u'): 4,
#  (' ', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'c', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 'u'): 2,
#  (' ', 'a', 'c', 'j', 'n', 't', 'u'): 2,
#  (' ', 'c', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'c', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'c', 'i', 'j', 'n', 't', 'u'): 2,
#  (' ', 'a', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'c', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 't', 'u'): 2,
#  (' ', 'c', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'i', 'j', 'u'): 3,
#  (' ', 'i', 'j', 't', 'u'): 6,
#  (' ', 'j', 'o', 'u'): 3,
#  (' ', 'i', 'j', 'o', 'u'): 4,
#  (' ', 'j', 'o', 't', 'u'): 6,
#  (' ', 'i', 'j', 'o', 't', 'u'): 4,
#  (' ', 'a', 'j', 'o', 'u'): 4,
#  (' ', 'a', 'i', 'j', 'o', 'u'): 6,
#  (' ', 'a', 'j', 'o', 't', 'u'): 8,
#  (' ', 'a', 'i', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'i', 'j', 'u'): 5,
#  (' ', 'a', 'i', 'j', 't', 'u'): 10,
#  (' ', 'a', 'i', 'i', 'j', 'u'): 2,
#  (' ', 'a', 'i', 'i', 'j', 't', 'u'): 2,
#  (' ', 'a', 'j', 't', 'u'): 6,
#  (' ', 'a', 'j', 't', 't', 'u'): 3,
#  (' ', 'j', 't', 'u'): 4,
#  (' ', 'j', 't', 't', 'u'): 2,
#  (' ', 'j', 'n'): 2,
#  (' ', 'i', 'j', 'n'): 4,
#  (' ', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'j', 'n'): 4,
#  (' ', 'j', 'n', 't'): 4,
#  (' ', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'i', 'j', 'n'): 4,
#  (' ', 'i', 'j', 'n', 't'): 4,
#  (' ', 'a', 'j', 'n', 'o'): 2,
#  (' ', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'j', 'n', 't'): 4,
#  (' ', 'a', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'i', 'j', 'n', 't'): 4,
#  (' ', 'a', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'j'): 3,
#  (' ', 'a', 'j', 't'): 6,
#  (' ', 'j', 'o'): 3,
#  (' ', 'a', 'j', 'o'): 4,
#  (' ', 'j', 'o', 't'): 6,
#  (' ', 'a', 'j', 'o', 't'): 4,
#  (' ', 'i', 'j', 'o'): 4,
#  (' ', 'a', 'i', 'j', 'o'): 6,
#  (' ', 'i', 'j', 'o', 't'): 8,
#  (' ', 'a', 'i', 'j', 'o', 't'): 6,
#  (' ', 'a', 'i', 'j'): 5,
#  (' ', 'a', 'i', 'j', 't'): 10,
#  (' ', 'a', 'a', 'i', 'j'): 2,
#  (' ', 'a', 'a', 'i', 'j', 't'): 2,
#  (' ', 'i', 'j', 't'): 6,
#  (' ', 'i', 'j', 't', 't'): 3,
#  (' ', 'j', 't'): 4,
#  (' ', 'j', 't', 't'): 2,
#  (' ', 'e', 'i', 'j'): 3,
#  (' ', 'e', 'i', 'j', 't'): 6,
#  (' ', 'e', 'j', 'o'): 3,
#  (' ', 'e', 'i', 'j', 'o'): 4,
#  (' ', 'e', 'j', 'o', 't'): 6,
#  (' ', 'e', 'i', 'j', 'o', 't'): 4,
#  (' ', 'a', 'e', 'j', 'o'): 4,
#  (' ', 'a', 'e', 'i', 'j', 'o'): 6,
#  (' ', 'a', 'e', 'j', 'o', 't'): 8,
#  (' ', 'a', 'e', 'i', 'j', 'o', 't'): 6,
#  (' ', 'a', 'e', 'i', 'j'): 5,
#  (' ', 'a', 'e', 'i', 'j', 't'): 10,
#  (' ', 'a', 'e', 'i', 'i', 'j'): 2,
#  (' ', 'a', 'e', 'i', 'i', 'j', 't'): 2,
#  (' ', 'a', 'e', 'j', 't'): 6,
#  (' ', 'a', 'e', 'j', 't', 't'): 3,
#  (' ', 'e', 'j', 't'): 4,
#  (' ', 'e', 'j', 't', 't'): 2,
#  (' ', 'c', 'e', 'j', 'n'): 2,
#  (' ', 'c', 'e', 'i', 'j', 'n'): 4,
#  (' ', 'c', 'e', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'c', 'e', 'j', 'n'): 4,
#  (' ', 'c', 'e', 'j', 'n', 't'): 4,
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n'): 4,
#  (' ', 'c', 'e', 'i', 'j', 'n', 't'): 4,
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o'): 2,
#  (' ', 'c', 'e', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'e', 'j', 'n', 't'): 4,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 't'): 4,
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'c', 'e', 'j'): 3,
#  (' ', 'a', 'c', 'e', 'j', 't'): 6,
#  (' ', 'c', 'e', 'j', 'o'): 3,
#  (' ', 'a', 'c', 'e', 'j', 'o'): 4,
#  (' ', 'c', 'e', 'j', 'o', 't'): 6,
#  (' ', 'a', 'c', 'e', 'j', 'o', 't'): 4,
#  (' ', 'c', 'e', 'i', 'j', 'o'): 4,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o'): 6,
#  (' ', 'c', 'e', 'i', 'j', 'o', 't'): 8,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o', 't'): 6,
#  (' ', 'a', 'c', 'e', 'i', 'j'): 5,
#  (' ', 'a', 'c', 'e', 'i', 'j', 't'): 10,
#  (' ', 'a', 'a', 'c', 'e', 'i', 'j'): 2,
#  (' ', 'a', 'a', 'c', 'e', 'i', 'j', 't'): 2,
#  (' ', 'c', 'e', 'i', 'j', 't'): 6,
#  (' ', 'c', 'e', 'i', 'j', 't', 't'): 3,
#  (' ', 'c', 'e', 'j', 't'): 4,
#  (' ', 'c', 'e', 'j', 't', 't'): 2,
#  ('c', 'e', 'j', 'n'): 2,
#  ('a', 'c', 'e', 'j', 'n'): 4,
#  ('c', 'e', 'j', 'n', 'o'): 2,
#  ('c', 'e', 'i', 'j', 'n'): 4,
#  ('c', 'e', 'j', 'n', 't'): 4,
#  ('a', 'c', 'e', 'j', 'n', 'o'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n'): 4,
#  ('a', 'c', 'e', 'j', 'n', 't'): 4,
#  ('c', 'e', 'i', 'j', 'n', 'o'): 2,
#  ('c', 'e', 'j', 'n', 'o', 't'): 2,
#  ('c', 'e', 'i', 'j', 'n', 't'): 4,
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o'): 2,
#  ('a', 'c', 'e', 'j', 'n', 'o', 't'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 't'): 4,
#  ('c', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  ('c', 'e', 'i', 'j'): 3,
#  ('c', 'e', 'i', 'j', 't'): 6,
#  ('c', 'e', 'j', 'o'): 3,
#  ('c', 'e', 'i', 'j', 'o'): 4,
#  ('c', 'e', 'j', 'o', 't'): 6,
#  ('c', 'e', 'i', 'j', 'o', 't'): 4,
#  ('a', 'c', 'e', 'j', 'o'): 4,
#  ('a', 'c', 'e', 'i', 'j', 'o'): 6,
#  ('a', 'c', 'e', 'j', 'o', 't'): 8,
#  ('a', 'c', 'e', 'i', 'j', 'o', 't'): 6,
#  ('a', 'c', 'e', 'i', 'j'): 5,
#  ('a', 'c', 'e', 'i', 'j', 't'): 10,
#  ('a', 'c', 'e', 'i', 'i', 'j'): 2,
#  ('a', 'c', 'e', 'i', 'i', 'j', 't'): 2,
#  ('a', 'c', 'e', 'j', 't'): 6,
#  ('a', 'c', 'e', 'j', 't', 't'): 3,
#  ('c', 'e', 'j', 't'): 4,
#  ('c', 'e', 'j', 't', 't'): 2,
#  ('a', 'c', 'e', 'j', 'u'): 3,
#  ('a', 'c', 'e', 'j', 't', 'u'): 6,
#  ('c', 'e', 'j', 'o', 'u'): 3,
#  ('a', 'c', 'e', 'j', 'o', 'u'): 4,
#  ('c', 'e', 'j', 'o', 't', 'u'): 6,
#  ('a', 'c', 'e', 'j', 'o', 't', 'u'): 4,
#  ('c', 'e', 'i', 'j', 'o', 'u'): 4,
#  ('a', 'c', 'e', 'i', 'j', 'o', 'u'): 6,
#  ('c', 'e', 'i', 'j', 'o', 't', 'u'): 8,
#  ('a', 'c', 'e', 'i', 'j', 'o', 't', 'u'): 6,
#  ('a', 'c', 'e', 'i', 'j', 'u'): 5,
#  ('a', 'c', 'e', 'i', 'j', 't', 'u'): 10,
#  ('a', 'a', 'c', 'e', 'i', 'j', 'u'): 2,
#  ('a', 'a', 'c', 'e', 'i', 'j', 't', 'u'): 2,
#  ('c', 'e', 'i', 'j', 't', 'u'): 6,
#  ('c', 'e', 'i', 'j', 't', 't', 'u'): 3,
#  ('c', 'e', 'j', 't', 'u'): 4,
#  ('c', 'e', 'j', 't', 't', 'u'): 2,
#  (' ', 'c', 'e', 'j', 'n', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'j', 'n', 'u'): 4,
#  (' ', 'c', 'e', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'c', 'e', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'c', 'e', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'a', 'c', 'e', 'j', 'n', 't', 'u'): 4,
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'c', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'c', 'e', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'c', 'e', 'i', 'j', 'u'): 3,
#  (' ', 'c', 'e', 'i', 'j', 't', 'u'): 6,
#  (' ', 'c', 'e', 'j', 'o', 'u'): 3,
#  (' ', 'c', 'e', 'i', 'j', 'o', 'u'): 4,
#  (' ', 'c', 'e', 'j', 'o', 't', 'u'): 6,
#  (' ', 'c', 'e', 'i', 'j', 'o', 't', 'u'): 4,
#  (' ', 'a', 'c', 'e', 'j', 'o', 'u'): 4,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o', 'u'): 6,
#  (' ', 'a', 'c', 'e', 'j', 'o', 't', 'u'): 8,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'c', 'e', 'i', 'j', 'u'): 5,
#  (' ', 'a', 'c', 'e', 'i', 'j', 't', 'u'): 10,
#  (' ', 'a', 'c', 'e', 'i', 'i', 'j', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'i', 'i', 'j', 't', 'u'): 2,
#  (' ', 'a', 'c', 'e', 'j', 't', 'u'): 6,
#  (' ', 'a', 'c', 'e', 'j', 't', 't', 'u'): 3,
#  (' ', 'c', 'e', 'j', 't', 'u'): 4,
#  (' ', 'c', 'e', 'j', 't', 't', 'u'): 2,
#  (' ', 'e', 'j', 'n', 'u'): 2,
#  (' ', 'e', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'e', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'e', 'j', 'n', 'u'): 4,
#  (' ', 'e', 'j', 'n', 't', 'u'): 4,
#  (' ', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 'u'): 4,
#  (' ', 'e', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'e', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'e', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  (' ', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 't', 'u'): 4,
#  (' ', 'a', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  (' ', 'a', 'e', 'j', 'u'): 3,
#  (' ', 'a', 'e', 'j', 't', 'u'): 6,
#  (' ', 'e', 'j', 'o', 'u'): 3,
#  (' ', 'a', 'e', 'j', 'o', 'u'): 4,
#  (' ', 'e', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'e', 'j', 'o', 't', 'u'): 4,
#  (' ', 'e', 'i', 'j', 'o', 'u'): 4,
#  (' ', 'a', 'e', 'i', 'j', 'o', 'u'): 6,
#  (' ', 'e', 'i', 'j', 'o', 't', 'u'): 8,
#  (' ', 'a', 'e', 'i', 'j', 'o', 't', 'u'): 6,
#  (' ', 'a', 'e', 'i', 'j', 'u'): 5,
#  (' ', 'a', 'e', 'i', 'j', 't', 'u'): 10,
#  (' ', 'a', 'a', 'e', 'i', 'j', 'u'): 2,
#  (' ', 'a', 'a', 'e', 'i', 'j', 't', 'u'): 2,
#  (' ', 'e', 'i', 'j', 't', 'u'): 6,
#  (' ', 'e', 'i', 'j', 't', 't', 'u'): 3,
#  (' ', 'e', 'j', 't', 'u'): 4,
#  (' ', 'e', 'j', 't', 't', 'u'): 2,
#  ('e', 'j', 'n', 'u'): 2,
#  ('c', 'e', 'j', 'n', 'u'): 2,
#  ('a', 'e', 'j', 'n', 'u'): 4,
#  ('e', 'j', 'n', 'o', 'u'): 2,
#  ('e', 'i', 'j', 'n', 'u'): 4,
#  ('e', 'j', 'n', 't', 'u'): 4,
#  ('a', 'c', 'e', 'j', 'n', 'u'): 2,
#  ('c', 'e', 'j', 'n', 'o', 'u'): 2,
#  ('c', 'e', 'i', 'j', 'n', 'u'): 2,
#  ('c', 'e', 'j', 'n', 't', 'u'): 2,
#  ('a', 'e', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'e', 'i', 'j', 'n', 'u'): 4,
#  ('a', 'e', 'j', 'n', 't', 'u'): 4,
#  ('e', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('e', 'j', 'n', 'o', 't', 'u'): 2,
#  ('e', 'i', 'j', 'n', 't', 'u'): 4,
#  ('a', 'c', 'e', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 'u'): 2,
#  ('a', 'c', 'e', 'j', 'n', 't', 'u'): 2,
#  ('c', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('c', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  ('c', 'e', 'i', 'j', 'n', 't', 'u'): 2,
#  ('a', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'e', 'i', 'j', 'n', 't', 'u'): 4,
#  ('e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'c', 'e', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 't', 'u'): 2,
#  ('c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('e', 'i', 'j', 'u'): 3,
#  ('e', 'i', 'j', 't', 'u'): 6,
#  ('e', 'j', 'o', 'u'): 3,
#  ('e', 'i', 'j', 'o', 'u'): 4,
#  ('e', 'j', 'o', 't', 'u'): 6,
#  ('e', 'i', 'j', 'o', 't', 'u'): 4,
#  ('a', 'e', 'j', 'o', 'u'): 4,
#  ('a', 'e', 'i', 'j', 'o', 'u'): 6,
#  ('a', 'e', 'j', 'o', 't', 'u'): 8,
#  ('a', 'e', 'i', 'j', 'o', 't', 'u'): 6,
#  ('a', 'e', 'i', 'j', 'u'): 5,
#  ('a', 'e', 'i', 'j', 't', 'u'): 10,
#  ('a', 'e', 'i', 'i', 'j', 'u'): 2,
#  ('a', 'e', 'i', 'i', 'j', 't', 'u'): 2,
#  ('a', 'e', 'j', 't', 'u'): 6,
#  ('a', 'e', 'j', 't', 't', 'u'): 3,
#  ('e', 'j', 't', 'u'): 4,
#  ('e', 'j', 't', 't', 'u'): 2,
#  ('e', 'j', 'n'): 2,
#  (' ', 'e', 'j', 'n'): 2,
#  ('e', 'i', 'j', 'n'): 4,
#  ('e', 'j', 'n', 'o'): 2,
#  ('a', 'e', 'j', 'n'): 4,
#  ('e', 'j', 'n', 't'): 4,
#  (' ', 'e', 'i', 'j', 'n'): 2,
#  (' ', 'e', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'e', 'j', 'n'): 2,
#  (' ', 'e', 'j', 'n', 't'): 2,
#  ('e', 'i', 'j', 'n', 'o'): 2,
#  ('a', 'e', 'i', 'j', 'n'): 4,
#  ('e', 'i', 'j', 'n', 't'): 4,
#  ('a', 'e', 'j', 'n', 'o'): 2,
#  ('e', 'j', 'n', 'o', 't'): 2,
#  ('a', 'e', 'j', 'n', 't'): 4,
#  (' ', 'e', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n'): 2,
#  (' ', 'e', 'i', 'j', 'n', 't'): 2,
#  (' ', 'a', 'e', 'j', 'n', 'o'): 2,
#  (' ', 'e', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'e', 'j', 'n', 't'): 2,
#  ('a', 'e', 'i', 'j', 'n', 'o'): 2,
#  ('e', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'e', 'i', 'j', 'n', 't'): 4,
#  ('a', 'e', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o'): 2,
#  (' ', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 't'): 2,
#  (' ', 'a', 'e', 'j', 'n', 'o', 't'): 2,
#  ('a', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'e', 'j'): 3,
#  ('a', 'e', 'j', 't'): 6,
#  ('e', 'j', 'o'): 3,
#  ('a', 'e', 'j', 'o'): 4,
#  ('e', 'j', 'o', 't'): 6,
#  ('a', 'e', 'j', 'o', 't'): 4,
#  ('e', 'i', 'j', 'o'): 4,
#  ('a', 'e', 'i', 'j', 'o'): 6,
#  ('e', 'i', 'j', 'o', 't'): 8,
#  ('a', 'e', 'i', 'j', 'o', 't'): 6,
#  ('a', 'e', 'i', 'j'): 5,
#  ('a', 'e', 'i', 'j', 't'): 10,
#  ('a', 'a', 'e', 'i', 'j'): 2,
#  ('a', 'a', 'e', 'i', 'j', 't'): 2,
#  ('e', 'i', 'j', 't'): 6,
#  ('e', 'i', 'j', 't', 't'): 3,
#  ('e', 'j', 't'): 4,
#  ('e', 'j', 't', 't'): 2,
#  ('j', 'n'): 2,
#  ('c', 'j', 'n'): 2,
#  ('j', 'n', 'u'): 2,
#  ('a', 'j', 'n'): 4,
#  ('j', 'n', 'o'): 2,
#  ('i', 'j', 'n'): 4,
#  ('j', 'n', 't'): 4,
#  ('c', 'j', 'n', 'u'): 2,
#  ('a', 'c', 'j', 'n'): 2,
#  ('c', 'j', 'n', 'o'): 2,
#  ('c', 'i', 'j', 'n'): 2,
#  ('c', 'j', 'n', 't'): 2,
#  ('a', 'j', 'n', 'u'): 2,
#  ('j', 'n', 'o', 'u'): 2,
#  ('i', 'j', 'n', 'u'): 2,
#  ('j', 'n', 't', 'u'): 2,
#  ('a', 'j', 'n', 'o'): 2,
#  ('a', 'i', 'j', 'n'): 4,
#  ('a', 'j', 'n', 't'): 4,
#  ('i', 'j', 'n', 'o'): 2,
#  ('j', 'n', 'o', 't'): 2,
#  ('i', 'j', 'n', 't'): 4,
#  ('a', 'c', 'j', 'n', 'u'): 2,
#  ('c', 'j', 'n', 'o', 'u'): 2,
#  ('c', 'i', 'j', 'n', 'u'): 2,
#  ('c', 'j', 'n', 't', 'u'): 2,
#  ('a', 'c', 'j', 'n', 'o'): 2,
#  ('a', 'c', 'i', 'j', 'n'): 2,
#  ('a', 'c', 'j', 'n', 't'): 2,
#  ('c', 'i', 'j', 'n', 'o'): 2,
#  ('c', 'j', 'n', 'o', 't'): 2,
#  ('c', 'i', 'j', 'n', 't'): 2,
#  ('a', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'i', 'j', 'n', 'u'): 2,
#  ('a', 'j', 'n', 't', 'u'): 2,
#  ('i', 'j', 'n', 'o', 'u'): 2,
#  ('j', 'n', 'o', 't', 'u'): 2,
#  ('i', 'j', 'n', 't', 'u'): 2,
#  ('a', 'i', 'j', 'n', 'o'): 2,
#  ('a', 'j', 'n', 'o', 't'): 2,
#  ('a', 'i', 'j', 'n', 't'): 4,
#  ('i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'c', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'c', 'i', 'j', 'n', 'u'): 2,
#  ('a', 'c', 'j', 'n', 't', 'u'): 2,
#  ('c', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('c', 'j', 'n', 'o', 't', 'u'): 2,
#  ('c', 'i', 'j', 'n', 't', 'u'): 2,
#  ('a', 'c', 'i', 'j', 'n', 'o'): 2,
#  ('a', 'c', 'j', 'n', 'o', 't'): 2,
#  ('a', 'c', 'i', 'j', 'n', 't'): 2,
#  ('c', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'i', 'j', 'n', 't', 'u'): 2,
#  ('i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'c', 'i', 'j', 'n', 'o', 'u'): 2,
#  ('a', 'c', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'i', 'j', 'n', 't', 'u'): 2,
#  ('c', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'i', 'j', 'n', 'o', 't'): 2,
#  ('a', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('a', 'c', 'i', 'j', 'n', 'o', 't', 'u'): 2,
#  ('i', 'j'): 3,
#  ('i', 'j', 't'): 6,
#  ('j', 'o'): 3,
#  ('i', 'j', 'o'): 4,
#  ('j', 'o', 't'): 6,
#  ('i', 'j', 'o', 't'): 4,
#  ('a', 'j', 'o'): 4,
#  ('a', 'i', 'j', 'o'): 6,
#  ('a', 'j', 'o', 't'): 8,
#  ('a', 'i', 'j', 'o', 't'): 6,
#  ('a', 'i', 'j'): 5,
#  ('a', 'i', 'j', 't'): 10,
#  ('a', 'i', 'i', 'j'): 2,
#  ('a', 'i', 'i', 'j', 't'): 2,
#  ('a', 'j', 't'): 6,
#  ('a', 'j', 't', 't'): 3,
#  ('j', 't'): 4,
#  ('j', 't', 't'): 2,
#  ('h', 'p'): 2,
#  ('h', 'p', 's'): 2,
#  ('i', 'p'): 2,
#  ('h', 'i', 'p'): 2,
#  ('i', 'p', 's'): 2,
#  ('h', 'i', 'p', 's'): 2,
#  ('g', 'p'): 2,
#  ('e', 'g', 'p'): 6,
#  ('g', 'p', 'r'): 4,
#  ('g', 'p', 's'): 2,
#  ('e', 'g', 'p', 'r'): 4,
#  ('e', 'g', 'p', 's'): 2,
#  ('g', 'p', 'r', 's'): 2,
#  ('e', 'g', 'p', 'r', 's'): 2,
#  ('g', 'n', 'p'): 2,
#  ('e', 'g', 'n', 'p'): 6,
#  ('n', 'p', 'r'): 2,
#  ('g', 'n', 'p', 'r'): 4,
#  ('e', 'n', 'p', 'r'): 6,
#  ('e', 'g', 'n', 'p', 'r'): 4,
#  ('n', 'p', 's'): 2,
#  ('n', 'p', 'r', 's'): 2,
#  ('g', 'n', 'p', 's'): 2,
#  ('e', 'n', 'p', 's'): 3,
#  ('g', 'n', 'p', 'r', 's'): 2,
#  ('e', 'n', 'p', 'r', 's'): 2,
#  ('e', 'g', 'n', 'p', 's'): 2,
#  ('e', 'g', 'n', 'p', 'r', 's'): 2,
#  ('e', 'n', 'p'): 3,
#  ('e', 'e', 'n', 'p'): 3,
#  ('a', 'n', 'p'): 2,
#  ('a', 'e', 'n', 'p'): 3,
#  ('a', 'g', 'p'): 2,
#  ('a', 'g', 'n', 'p'): 2,
#  ('a', 'e', 'g', 'p'): 6,
#  ('a', 'e', 'g', 'n', 'p'): 2,
#  ('a', 'p', 'r'): 2,
#  ('a', 'g', 'p', 'r'): 4,
#  ('a', 'n', 'p', 'r'): 2,
#  ('a', 'e', 'p', 'r'): 6,
#  ('a', 'g', 'n', 'p', 'r'): 2,
#  ('a', 'e', 'g', 'p', 'r'): 4,
#  ('a', 'e', 'n', 'p', 'r'): 2,
#  ('a', 'e', 'g', 'n', 'p', 'r'): 2,
#  ('a', 'p', 'r', 's'): 2,
#  ('a', 'e', 'p', 'r', 's'): 6,
#  ('a', 'g', 'p', 's'): 2,
#  ('a', 'g', 'p', 'r', 's'): 4,
#  ('a', 'e', 'g', 'p', 's'): 6,
#  ('a', 'e', 'g', 'p', 'r', 's'): 4,
#  ('a', 'n', 'p', 's'): 2,
#  ('a', 'g', 'n', 'p', 's'): 2,
#  ('a', 'n', 'p', 'r', 's'): 2,
#  ('a', 'e', 'n', 'p', 's'): 3,
#  ('a', 'g', 'n', 'p', 'r', 's'): 2,
#  ('a', 'e', 'g', 'n', 'p', 's'): 2,
#  ('a', 'e', 'n', 'p', 'r', 's'): 2,
#  ('a', 'e', 'g', 'n', 'p', 'r', 's'): 2,
#  ('a', 'e', 'p', 's'): 3,
#  ('a', 'e', 'e', 'p', 's'): 3,
#  ('a', 'e', 'p'): 3,
#  ('a', 'e', 'e', 'p'): 3,
#  ('p', 's'): 3,
#  ('p', 'r'): 3,
#  ('p', 'r', 's'): 3,
#  ('e', 'p', 's'): 3,
#  ('e', 'p', 'r', 's'): 6,
#  ('e', 'e', 'p', 's'): 3,
#  ('e', 'e', 'p', 'r', 's'): 3,
#  ('e', 'e', 'p'): 3,
#  ('e', 'e', 'p', 'r'): 6,
#  ('e', 'p', 'r'): 6,
#  ('e', 'p', 'r', 'r'): 3,
#  (' ', 'o', 'v'): 2,
#  (' ', 'l', 'o', 'v'): 4,
#  (' ', 'i', 'o', 'v'): 4,
#  (' ', 'e', 'o', 'v'): 2,
#  (' ', 'i', 'l', 'o', 'v'): 4,
#  (' ', 'e', 'l', 'o', 'v'): 2,
#  (' ', 'e', 'i', 'o', 'v'): 2,
#  (' ', 'e', 'i', 'l', 'o', 'v'): 2,
#  (' ', 'i', 'v'): 3,
#  (' ', 'e', 'i', 'v'): 5,
#  (' ', 'i', 'l', 'v'): 5,
#  (' ', 'i', 'i', 'l', 'v'): 2,
#  (' ', 'e', 'e', 'l', 'v'): 3,
#  (' ', 'e', 'e', 'i', 'l', 'v'): 3,
#  (' ', 'e', 'i', 'l', 'v'): 7,
#  (' ', 'e', 'i', 'i', 'l', 'v'): 2,
#  (' ', 'e', 'v'): 4,
#  (' ', 'e', 'e', 'v'): 3,
#  ('a', 'e', 'v'): 3,
#  ('a', 'e', 'e', 'v'): 3,
#  ('a', 'o', 'v'): 4,
#  ('a', 'o', 'o', 'v'): 2,
#  ('l', 'o', 'v'): 4,
#  ('e', 'l', 'o', 'v'): 4,
#  ('l', 'o', 'o', 'v'): 2,
#  ('e', 'l', 'o', 'o', 'v'): 2,
#  ('e', 'l', 'v'): 5,
#  ('e', 'e', 'l', 'v'): 3,
#  ('i', 'o', 'v'): 4,
#  ('e', 'i', 'o', 'v'): 4,
#  ('i', 'l', 'o', 'v'): 8,
#  ('i', 'o', 'o', 'v'): 2,
#  ('e', 'i', 'l', 'o', 'v'): 4,
#  ('e', 'i', 'o', 'o', 'v'): 2,
#  ('i', 'l', 'o', 'o', 'v'): 2,
#  ('e', 'i', 'l', 'o', 'o', 'v'): 2,
#  ('i', 'l', 'v'): 5,
#  ('i', 'l', 'l', 'v'): 2,
#  ('e', 'e', 'i', 'v'): 3,
#  ('e', 'e', 'i', 'l', 'v'): 3,
#  ('e', 'i', 'l', 'v'): 7,
#  ('e', 'i', 'l', 'l', 'v'): 2,
#  ('o', 'v'): 4,
#  ('o', 'o', 'v'): 2,
#  ('e', 'o', 'v'): 2,
#  ('e', 'e', 'v'): 3,
#  ('f', 'r', 't', 'u'): 3,
#  (' ', 'f', 'r', 't', 'u'): 6,
#  ('f', 'o', 'r', 't', 'u'): 6,
#  (' ', 'f', 'o', 'r', 't', 'u'): 6,
#  ('f', 'r', 'u', 'w'): 3,
#  ('f', 'r', 't', 'u', 'w'): 4,
#  (' ', 'f', 'r', 'u', 'w'): 6,
#  ('f', 'o', 'r', 'u', 'w'): 6,
#  (' ', 'f', 'r', 't', 'u', 'w'): 4,
#  ('f', 'o', 'r', 't', 'u', 'w'): 4,
#  (' ', 'f', 'o', 'r', 'u', 'w'): 6,
#  (' ', 'f', 'o', 'r', 't', 'u', 'w'): 4,
#  ('f', 'l', 'r', 't', 'u'): 4,
#  ('f', 'l', 'r', 't', 'u', 'w'): 6,
#  ('f', 'l', 'o', 'r', 't', 'u'): 8,
#  (' ', 'f', 'l', 'r', 't', 'u'): 8,
#  ('f', 'l', 'o', 'r', 't', 'u', 'w'): 6,
#  (' ', 'f', 'l', 'r', 't', 'u', 'w'): 6,
#  (' ', 'f', 'l', 'o', 'r', 't', 'u'): 8,
#  (' ', 'f', 'l', 'o', 'r', 't', 'u', 'w'): 6,
#  ('f', 'l', 'r', 'u', 'w'): 5,
#  ('f', 'l', 'o', 'r', 'u', 'w'): 10,
#  (' ', 'f', 'l', 'r', 'u', 'w'): 10,
#  ('f', 'l', 'r', 'u', 'w', 'w'): 2,
#  (' ', 'f', 'l', 'o', 'r', 'u', 'w'): 10,
#  ('f', 'l', 'o', 'r', 'u', 'w', 'w'): 2,
#  (' ', 'f', 'l', 'r', 'u', 'w', 'w'): 2,
#  (' ', 'f', 'l', 'o', 'r', 'u', 'w', 'w'): 2,
#  (' ', 'f', 'l', 'r', 'u'): 6,
#  (' ', ' ', 'f', 'l', 'r', 'u'): 3,
#  ('f', 'l', 'o', 'r', 'u'): 6,
#  (' ', 'f', 'l', 'o', 'r', 'u'): 12,
#  ('f', 'l', 'o', 'o', 'r', 'u'): 3,
#  (' ', 'f', 'l', 'o', 'o', 'r', 'u'): 3,
#  ('f', 'o', 'r', 'u'): 4,
#  ('f', 'o', 'o', 'r', 'u'): 2,
#  (' ', 'f', 'r', 'u'): 4,
#  (' ', 'f', 'o', 'r', 'u'): 8,
#  (' ', ' ', 'f', 'r', 'u'): 2,
#  (' ', ' ', 'f', 'o', 'r', 'u'): 2,
#  ('e', 'f', 'u'): 2,
#  ('e', 'f', 'r', 'u'): 2,
#  ('e', 'f', 't', 'u'): 2,
#  ('e', 'f', 'u', 'w'): 4,
#  ('e', 'f', 'l', 'u'): 4,
#  ('e', 'f', 'o', 'u'): 4,
#  (' ', 'e', 'f', 'u'): 4,
#  ('e', 'f', 'r', 't', 'u'): 2,
#  ('e', 'f', 'r', 'u', 'w'): 2,
#  ('e', 'f', 'l', 'r', 'u'): 2,
#  ('e', 'f', 'o', 'r', 'u'): 2,
#  (' ', 'e', 'f', 'r', 'u'): 2,
#  ('e', 'f', 't', 'u', 'w'): 2,
#  ('e', 'f', 'l', 't', 'u'): 2,
#  ('e', 'f', 'o', 't', 'u'): 2,
#  (' ', 'e', 'f', 't', 'u'): 2,
#  ('e', 'f', 'l', 'u', 'w'): 4,
#  ('e', 'f', 'o', 'u', 'w'): 4,
#  (' ', 'e', 'f', 'u', 'w'): 4,
#  ('e', 'f', 'l', 'o', 'u'): 4,
#  (' ', 'e', 'f', 'l', 'u'): 4,
#  (' ', 'e', 'f', 'o', 'u'): 4,
#  ('e', 'f', 'r', 't', 'u', 'w'): 2,
#  ('e', 'f', 'l', 'r', 't', 'u'): 2,
#  ('e', 'f', 'o', 'r', 't', 'u'): 2,
#  (' ', 'e', 'f', 'r', 't', 'u'): 2,
#  ('e', 'f', 'l', 'r', 'u', 'w'): 2,
#  ('e', 'f', 'o', 'r', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'r', 'u', 'w'): 2,
#  ('e', 'f', 'l', 'o', 'r', 'u'): 2,
#  (' ', 'e', 'f', 'l', 'r', 'u'): 2,
#  (' ', 'e', 'f', 'o', 'r', 'u'): 2,
#  ('e', 'f', 'l', 't', 'u', 'w'): 2,
#  ('e', 'f', 'o', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 't', 'u', 'w'): 2,
#  ('e', 'f', 'l', 'o', 't', 'u'): 2,
#  (' ', 'e', 'f', 'l', 't', 'u'): 2,
#  (' ', 'e', 'f', 'o', 't', 'u'): 2,
#  ('e', 'f', 'l', 'o', 'u', 'w'): 4,
#  (' ', 'e', 'f', 'l', 'u', 'w'): 4,
#  (' ', 'e', 'f', 'o', 'u', 'w'): 4,
#  (' ', 'e', 'f', 'l', 'o', 'u'): 4,
#  ('e', 'f', 'l', 'r', 't', 'u', 'w'): 2,
#  ('e', 'f', 'o', 'r', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'r', 't', 'u', 'w'): 2,
#  ('e', 'f', 'l', 'o', 'r', 't', 'u'): 2,
#  (' ', 'e', 'f', 'l', 'r', 't', 'u'): 2,
#  (' ', 'e', 'f', 'o', 'r', 't', 'u'): 2,
#  ('e', 'f', 'l', 'o', 'r', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'r', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'o', 'r', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'o', 'r', 'u'): 2,
#  ('e', 'f', 'l', 'o', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'o', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'o', 't', 'u'): 2,
#  (' ', 'e', 'f', 'l', 'o', 'u', 'w'): 4,
#  ('e', 'f', 'l', 'o', 'r', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'r', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'o', 'r', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'o', 'r', 't', 'u'): 2,
#  (' ', 'e', 'f', 'l', 'o', 'r', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'o', 't', 'u', 'w'): 2,
#  (' ', 'e', 'f', 'l', 'o', 'r', 't', 'u', 'w'): 2,
#  ('f', 'l', 'u'): 3,
#  ('f', 'l', 'o', 'u'): 6,
#  (' ', 'f', 'l', 'u'): 6,
#  (' ', 'f', 'l', 'o', 'u'): 6,
#  ('f', 'u', 'w'): 3,
#  ('f', 'l', 'u', 'w'): 5,
#  ('f', 'o', 'u', 'w'): 6,
#  (' ', 'f', 'u', 'w'): 6,
#  ('f', 'l', 'o', 'u', 'w'): 5,
#  (' ', 'f', 'l', 'u', 'w'): 5,
#  (' ', 'f', 'o', 'u', 'w'): 6,
#  (' ', 'f', 'l', 'o', 'u', 'w'): 5,
#  ('f', 't', 'u', 'w'): 4,
#  (' ', 'f', 't', 'u', 'w'): 8,
#  ('f', 'o', 't', 'u', 'w'): 8,
#  (' ', 'f', 'o', 't', 'u', 'w'): 8,
#  ('f', 'l', 't', 'u'): 4,
#  ('f', 'l', 't', 'u', 'w'): 6,
#  (' ', 'f', 'l', 't', 'u'): 8,
#  ('f', 'l', 'o', 't', 'u'): 8,
#  (' ', 'f', 'l', 't', 'u', 'w'): 6,
#  ('f', 'l', 'o', 't', 'u', 'w'): 6,
#  (' ', 'f', 'l', 'o', 't', 'u'): 8,
#  (' ', 'f', 'l', 'o', 't', 'u', 'w'): 6,
#  ('f', 'o', 't', 'u'): 6,
#  ('f', 'o', 'o', 't', 'u'): 3,
#  (' ', 'f', 't', 'u'): 6,
#  (' ', 'f', 'o', 't', 'u'): 12,
#  (' ', ' ', 'f', 't', 'u'): 3,
#  (' ', ' ', 'f', 'o', 't', 'u'): 3,
#  (' ', 'f', 'u'): 4,
#  (' ', ' ', 'f', 'u'): 2,
#  ('f', 'o', 'u'): 4,
#  (' ', 'f', 'o', 'u'): 8,
#  ('f', 'o', 'o', 'u'): 2,
#  (' ', 'f', 'o', 'o', 'u'): 2,
#  (' ', 'e', 'e', 'f', 'h', 'r'): 3,
#  (' ', 'e', 'e', 'f', 'h', 'o', 'r'): 7,
#  (' ', 'e', 'f', 'h', 'o', 'r'): 14,
#  (' ', 'e', 'f', 'h', 'o', 'o', 'r'): 10,
#  (' ', 'f', 'h', 'o', 'r'): 7,
#  (' ', 'f', 'h', 'o', 'o', 'r'): 5,
#  ('e', 'e', 'f', 'h', 'r'): 2,
#  ('e', 'e', 'f', 'h', 'o', 'r'): 5,
#  ('e', 'f', 'h', 'o', 'r'): 10,
#  ('e', 'f', 'h', 'o', 'o', 'r'): 8,
#  ('f', 'h', 'o', 'r'): 5,
#  ('f', 'h', 'o', 'o', 'r'): 4,
#  ('f', 'h', 'l'): 2,
#  ('f', 'h', 'l', 'r'): 2,
#  (' ', 'f', 'h', 'l'): 4,
#  ('e', 'f', 'h', 'l'): 4,
#  ('f', 'h', 'l', 'o'): 4,
#  (' ', 'f', 'h', 'l', 'r'): 2,
#  ('e', 'f', 'h', 'l', 'r'): 2,
#  ('f', 'h', 'l', 'o', 'r'): 2,
#  (' ', 'e', 'f', 'h', 'l'): 4,
#  (' ', 'f', 'h', 'l', 'o'): 4,
#  ('e', 'f', 'h', 'l', 'o'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'r'): 2,
#  (' ', 'f', 'h', 'l', 'o', 'r'): 2,
#  ('e', 'f', 'h', 'l', 'o', 'r'): 2,
#  (' ', 'e', 'f', 'h', 'l', 'o'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'o', 'r'): 2,
#  ('f', 'h', 'w'): 2,
#  ('f', 'h', 'l', 'w'): 4,
#  ('f', 'h', 'r', 'w'): 2,
#  (' ', 'f', 'h', 'w'): 4,
#  ('e', 'f', 'h', 'w'): 4,
#  ('f', 'h', 'o', 'w'): 4,
#  ('f', 'h', 'l', 'r', 'w'): 2,
#  (' ', 'f', 'h', 'l', 'w'): 4,
#  ('e', 'f', 'h', 'l', 'w'): 4,
#  ('f', 'h', 'l', 'o', 'w'): 4,
#  (' ', 'f', 'h', 'r', 'w'): 2,
#  ('e', 'f', 'h', 'r', 'w'): 2,
#  ('f', 'h', 'o', 'r', 'w'): 2,
#  (' ', 'e', 'f', 'h', 'w'): 4,
#  (' ', 'f', 'h', 'o', 'w'): 4,
#  ('e', 'f', 'h', 'o', 'w'): 4,
#  (' ', 'f', 'h', 'l', 'r', 'w'): 2,
#  ('e', 'f', 'h', 'l', 'r', 'w'): 2,
#  ('f', 'h', 'l', 'o', 'r', 'w'): 2,
#  (' ', 'e', 'f', 'h', 'l', 'w'): 4,
#  (' ', 'f', 'h', 'l', 'o', 'w'): 4,
#  ('e', 'f', 'h', 'l', 'o', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'r', 'w'): 2,
#  (' ', 'f', 'h', 'o', 'r', 'w'): 2,
#  ('e', 'f', 'h', 'o', 'r', 'w'): 2,
#  (' ', 'e', 'f', 'h', 'o', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'r', 'w'): 2,
#  (' ', 'f', 'h', 'l', 'o', 'r', 'w'): 2,
#  ('e', 'f', 'h', 'l', 'o', 'r', 'w'): 2,
#  (' ', 'e', 'f', 'h', 'l', 'o', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'o', 'r', 'w'): 2,
#  (' ', 'e', 'f', 'h', 'l', 'o', 'r', 'w'): 2,
#  ('f', 'h', 't', 'w'): 2,
#  (' ', 'f', 'h', 't', 'w'): 4,
#  ('e', 'f', 'h', 't', 'w'): 4,
#  ('f', 'h', 'o', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 't', 'w'): 4,
#  (' ', 'f', 'h', 'o', 't', 'w'): 4,
#  ('e', 'f', 'h', 'o', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'o', 't', 'w'): 4,
#  ('f', 'h', 'l', 't'): 2,
#  ('f', 'h', 'l', 't', 'w'): 4,
#  (' ', 'f', 'h', 'l', 't'): 4,
#  ('e', 'f', 'h', 'l', 't'): 4,
#  ('f', 'h', 'l', 'o', 't'): 4,
#  (' ', 'f', 'h', 'l', 't', 'w'): 4,
#  ('e', 'f', 'h', 'l', 't', 'w'): 4,
#  ('f', 'h', 'l', 'o', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'l', 't'): 4,
#  (' ', 'f', 'h', 'l', 'o', 't'): 4,
#  ('e', 'f', 'h', 'l', 'o', 't'): 4,
#  (' ', 'e', 'f', 'h', 'l', 't', 'w'): 4,
#  (' ', 'f', 'h', 'l', 'o', 't', 'w'): 4,
#  ('e', 'f', 'h', 'l', 'o', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'o', 't'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'o', 't', 'w'): 4,
#  ('f', 'h', 'l', 'r', 't'): 2,
#  (' ', 'f', 'h', 'l', 'r', 't'): 4,
#  ('e', 'f', 'h', 'l', 'r', 't'): 4,
#  ('f', 'h', 'l', 'o', 'r', 't'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'r', 't'): 4,
#  (' ', 'f', 'h', 'l', 'o', 'r', 't'): 4,
#  ('e', 'f', 'h', 'l', 'o', 'r', 't'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'o', 'r', 't'): 4,
#  ('f', 'h', 'r', 't', 'w'): 2,
#  ('f', 'h', 'l', 'r', 't', 'w'): 4,
#  (' ', 'f', 'h', 'r', 't', 'w'): 4,
#  ('e', 'f', 'h', 'r', 't', 'w'): 4,
#  ('f', 'h', 'o', 'r', 't', 'w'): 4,
#  (' ', 'f', 'h', 'l', 'r', 't', 'w'): 4,
#  ('e', 'f', 'h', 'l', 'r', 't', 'w'): 4,
#  ('f', 'h', 'l', 'o', 'r', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'r', 't', 'w'): 4,
#  (' ', 'f', 'h', 'o', 'r', 't', 'w'): 4,
#  ('e', 'f', 'h', 'o', 'r', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'r', 't', 'w'): 4,
#  (' ', 'f', 'h', 'l', 'o', 'r', 't', 'w'): 4,
#  ('e', 'f', 'h', 'l', 'o', 'r', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'o', 'r', 't', 'w'): 4,
#  (' ', 'e', 'f', 'h', 'l', 'o', 'r', 't', 'w'): 4,
#  (' ', 'e', 'e', 'f', 'h', 'r', 't'): 3,
#  (' ', 'e', 'e', 'f', 'h', 'o', 'r', 't'): 7,
#  (' ', 'e', 'f', 'h', 'o', 'r', 't'): 14,
#  (' ', 'e', 'f', 'h', 'o', 'o', 'r', 't'): 10,
#  (' ', 'f', 'h', 'o', 'r', 't'): 7,
#  ...}

# %%
rules=pyfpgrowth.generate_association_rules(patterns,0.7)

# %%
rules
# Out:
# {('n', 'x'): (('a', 'e', 'i', 't'), 1.0),
#  ('i', 'x'): (('a', 'e', 't'), 3.6666666666666665),
#  (' ', 'n', 'x'): (('a', 'e', 'i', 't'), 1.0),
#  ('i', 'n', 'x'): (('a', 't'), 1.0),
#  ('n', 't', 'x'): (('a', 'i'), 1.0),
#  (' ', 'a', 'x'): (('e', 'i', 't'), 3.6666666666666665),
#  ('a', 'n', 'x'): (('i', 't'), 1.0),
#  ('e', 'n', 'x'): (('a', 'i', 't'), 1.0),
#  ('i', 't', 'x'): (('a', 'e'), 2.2),
#  (' ', 'i', 'n', 'x'): (('a', 't'), 1.0),
#  (' ', 'i', 't', 'x'): (('a', 'e'), 2.2),
#  (' ', 'n', 't', 'x'): (('a', 'i'), 1.0),
#  ('i', 'n', 't', 'x'): (('a',), 1.0),
#  ('a', 'i', 'x'): (('e', 't'), 2.2),
#  (' ', 'a', 'i', 'x'): (('e', 't'), 2.2),
#  (' ', 'a', 'n', 'x'): (('i', 't'), 1.0),
#  ('a', 'i', 'n', 'x'): (('t',), 1.0),
#  (' ', 'e', 'n', 'x'): (('a', 'i', 't'), 1.0),
#  ('e', 'i', 'n', 'x'): (('a', 't'), 1.0),
#  ('a', 't', 'x'): (('e', 'i'), 2.2),
#  (' ', 'a', 't', 'x'): (('e', 'i'), 2.2),
#  ('a', 'n', 't', 'x'): (('i',), 1.0),
#  ('e', 'n', 't', 'x'): (('a', 'i'), 1.0),
#  ('a', 'e', 'n', 'x'): (('i', 't'), 1.0),
#  (' ', 'a', 'i', 'n', 'x'): (('t',), 1.0),
#  (' ', 'a', 'n', 't', 'x'): (('i',), 1.0),
#  (' ', 'i', 'n', 't', 'x'): (('a',), 1.0),
#  ('a', 'i', 'n', 't', 'x'): ((' ',), 1.0),
#  (' ', 'e', 'i', 'n', 'x'): (('a', 't'), 1.0),
#  (' ', 'e', 'n', 't', 'x'): (('a', 'i'), 1.0),
#  ('e', 'i', 'n', 't', 'x'): (('a',), 1.0),
#  (' ', 'a', 'e', 'n', 'x'): (('i', 't'), 1.0),
#  ('a', 'e', 'i', 'n', 'x'): (('t',), 1.0),
#  ('a', 'e', 'n', 't', 'x'): (('i',), 1.0),
#  (' ', 'a', 'e', 'i', 'n', 'x'): (('t',), 1.0),
#  (' ', 'a', 'e', 'n', 't', 'x'): (('i',), 1.0),
#  (' ', 'e', 'i', 'n', 't', 'x'): (('a',), 1.0),
#  ('a', 'e', 'i', 'n', 't', 'x'): ((' ',), 1.0),
#  ('e', 'x'): ((), 0.75),
#  (' ', 'e', 'x'): ((), 0.75),
#  (' ', 'a', 'a'): (('e',), 1.5),
#  ('e', 'e', 'x'): (('a', 'i', 't'), 1.0),
#  (' ', 'e', 'e', 'x'): (('a', 'i', 't'), 1.0),
#  ('e', 'e', 't', 'x'): (('a', 'i'), 1.0),
#  ('a', 'e', 'e', 'x'): (('i', 't'), 1.0),
#  (' ', 'e', 'e', 't', 'x'): (('a', 'i'), 1.0),
#  ('a', 'e', 'e', 't', 'x'): (('i',), 1.0),
#  (' ', 'a', 'e', 'x'): (('i', 't'), 2.2),
#  ('a', 'e', 't', 'x'): (('i',), 1.5714285714285714),
#  (' ', 'a', 'a', 't', 'x'): (('i',), 1.0),
#  ('a', 'i', 't', 'x'): (('e',), 1.2222222222222223),
#  (' ', 'a', 'a', 'i', 'x'): (('e',), 1.0),
#  (' ', 'e', 'e', 'i', 'x'): (('a', 't'), 1.0),
#  ('e', 'e', 'i', 't', 'x'): (('a',), 1.0),
#  ('a', 'e', 'e', 'i', 'x'): (('t',), 1.0),
#  (' ', 'a', 'e', 'e', 'i', 'x'): (('t',), 1.0),
#  (' ', 'a', 'e', 'e', 't', 'x'): (('i',), 1.0),
#  (' ', 'e', 'e', 'i', 't', 'x'): (('a',), 1.0),
#  ('a', 'e', 'e', 'i', 't', 'x'): ((' ',), 1.0),
#  ('e', 'i', 'x'): (('a', 't'), 2.2),
#  ('a', 'e', 'i', 'x'): (('t',), 1.5714285714285714),
#  ('e', 'i', 't', 'x'): (('a',), 1.5714285714285714),
#  ('e', 'i'): (('o',), 1.0),
#  (' ', 'e', 'i'): (('a', 't'), 1.2142857142857142),
#  ('a', 'i', 't'): (('e',), 1.3076923076923077),
#  ('e', 'i', 't'): (('a',), 1.3076923076923077),
#  (' ', 'a', 'i', 't'): (('e',), 1.3076923076923077),
#  (' ', 'e', 'i', 't'): (('a',), 1.3076923076923077),
#  (' ', 'a', 'e', 'i', 'x'): (('t',), 1.5714285714285714),
#  (' ', 'a', 'e', 't', 'x'): (('i',), 1.5714285714285714),
#  (' ', 'a', 'i', 't', 'x'): (('e',), 1.2222222222222223),
#  (' ', 'e', 'i', 't', 'x'): (('a',), 1.5714285714285714),
#  ('a', 'e', 'i', 't', 'x'): ((' ',), 1.0),
#  (' ', 'i', 't', 't', 'x'): (('a', 'e'), 1.0),
#  ('a', 't', 't', 'x'): (('e', 'i'), 1.0),
#  ('a', 'e', 't', 't', 'x'): (('i',), 1.0),
#  (' ', 'e', 'i', 't', 't', 'x'): (('a',), 1.0),
#  ('a', 'e', 'i', 't', 't', 'x'): ((' ',), 1.0),
#  ('i', 'i', 't'): ((' ', 'a', 'e', 'n', 'o'), 1.0),
#  ('e', 'i', 'i', 't'): ((' ', 'a', 'n', 'o'), 1.0),
#  ('i', 'i', 't', 'x'): (('a',), 1.0),
#  ('a', 'i', 'i'): ((' ', 'e', 'n', 'o', 't'), 1.0),
#  ('a', 'i', 'i', 'x'): (('e',), 1.0),
#  ('a', 'e', 'i', 'i'): ((' ', 'n', 'o', 't'), 1.0),
#  ('j', 't'): (('a',), 0.75),
#  ('t', 'u'): (('o',), 0.7142857142857143),
#  ('a', 'j', 't'): (('i',), 1.6666666666666667),
#  ('a', 'j', 'u'): (('e', 't'), 1.0),
#  ('j', 't', 'u'): (('e',), 1.0),
#  ('j', 'o'): (('a', 'i', 't'), 2.0),
#  ('a', 'j', 'o'): (('i', 't'), 1.5),
#  ('j', 'o', 'u'): (('a', 'e', 'i', 't'), 2.0),
#  ('j', 'o', 't'): (('a', 'i'), 1.0),
#  ('a', 'j', 'o', 'u'): (('e', 'i', 't'), 1.5),
#  ('i', 'j'): (('a', 't'), 3.3333333333333335),
#  ('i', 'j', 'o'): (('a', 't'), 1.5),
#  ('i', 'o', 'u'): (('a', 't'), 1.5),
#  ('a', 'i', 'j'): (('t',), 2.0),
#  ('a', 'i', 'u'): (('t',), 2.0),
#  ('a', 'i', 'j', 'o'): (('t',), 1.0),
#  ('a', 'i', 'j', 'u'): (('e', 't'), 2.0),
#  ('a', 'i', 'o', 'u'): (('t',), 1.0),
#  ('i', 'j', 'o', 'u'): (('a', 'e', 't'), 1.5),
#  ('i', 'j', 't'): (('a',), 1.6666666666666667),
#  ('i', 't', 'u'): (('a',), 1.6666666666666667),
#  ('i', 'j', 'o', 't'): (('a',), 1.5),
#  ('i', 'j', 't', 'u'): (('a', 'e'), 1.6666666666666667),
#  ('i', 'o', 't', 'u'): (('a',), 0.75),
#  ('j', 'o', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  ('a', 'j', 'o', 't'): (('i',), 0.75),
#  ('a', 'j', 't', 'u'): (('e',), 1.0),
#  ('a', 'i', 'j', 'o', 't'): (('e',), 1.0),
#  ('a', 'i', 'j', 'o', 'u'): (('e', 't'), 1.0),
#  ('a', 'i', 'o', 't', 'u'): ((' ',), 1.0),
#  ('a', 'j', 'o', 't', 'u'): (('e', 'i'), 1.5),
#  ('i', 'j', 'o', 't', 'u'): (('a', 'e'), 0.75),
#  ('a', 't', 'u'): (('o',), 1.5555555555555556),
#  ('a', 'i', 'j', 't'): (('e',), 1.0),
#  ('a', 'i', 't', 'u'): ((' ',), 1.0),
#  ('a', 'a', 'i', 'u'): (('t',), 1.0),
#  ('a', 'a', 'i', 'j', 'u'): ((' ', 'e', 't'), 1.0),
#  ('a', 'a', 'i', 't', 'u'): ((' ',), 1.0),
#  ('j', 't', 't'): (('a',), 1.5),
#  ('t', 't', 'u'): (('o',), 1.6666666666666667),
#  ('i', 't', 't', 'u'): ((' ',), 1.0),
#  ('j', 't', 't', 'u'): (('e',), 1.0),
#  ('c', 'i', 'u'): (('a', 'o', 't'), 2.0),
#  ('c', 'j', 't'): ((' ', 'e', 'u'), 1.0),
#  ('c', 't', 'u'): (('o',), 0.75),
#  ('c', 'i', 'j', 't'): ((' ', 'a', 'e', 'u'), 1.6666666666666667),
#  ('c', 'i', 'j', 'u'): ((' ', 'a', 'e', 't'), 3.3333333333333335),
#  ('c', 'i', 't', 'u'): (('a', 'o'), 1.0),
#  ('c', 'j', 't', 'u'): ((' ', 'e'), 1.0),
#  ('c', 'j', 'o'): ((' ', 'a', 'e', 'i', 't', 'u'), 2.0),
#  ('c', 'i', 'o'): (('a', 't'), 1.5),
#  ('c', 'i', 'j', 'o'): ((' ', 'a', 'e', 't', 'u'), 1.5),
#  ('c', 'i', 'o', 'u'): (('a', 't'), 1.5),
#  ('c', 'j', 'o', 'u'): ((' ', 'a', 'e', 'i', 't'), 2.0),
#  ('c', 'j', 'o', 't'): ((' ', 'a', 'e', 'i', 'u'), 1.0),
#  ('c', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('c', 'i', 'j', 'o', 'u'): ((' ', 'a', 'e', 't'), 1.5),
#  ('a', 'c', 'j'): ((' ', 'e', 't', 'u'), 1.0),
#  ('a', 'c', 'u'): (('i', 'o', 't'), 2.0),
#  ('a', 'c', 'j', 'o'): ((' ', 'e', 'i', 't', 'u'), 1.5),
#  ('a', 'c', 'o', 'u'): (('i', 't'), 1.5),
#  ('a', 'c', 'i'): (('t',), 1.6666666666666667),
#  ('a', 'c', 'i', 'j'): ((' ', 'e', 't', 'u'), 2.0),
#  ('a', 'c', 'i', 'o'): (('t',), 1.0),
#  ('a', 'c', 'i', 'u'): (('o', 't'), 1.2),
#  ('a', 'c', 'i', 'j', 'o'): ((' ', 'e', 't', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'u'): ((' ', 'e', 't'), 2.0),
#  ('a', 'c', 'i', 'o', 'u'): (('t',), 1.0),
#  ('a', 'c', 'j', 'o', 'u'): ((' ', 'e', 'i', 't'), 1.5),
#  ('a', 'c', 'j', 't'): ((' ', 'e', 'u'), 1.0),
#  ('a', 'c', 't', 'u'): (('i', 'o'), 1.0),
#  ('a', 'c', 'j', 'o', 't'): ((' ', 'e', 'i', 'u'), 1.5),
#  ('a', 'c', 'j', 't', 'u'): ((' ', 'e'), 1.0),
#  ('a', 'c', 'o', 't', 'u'): (('i',), 0.75),
#  ('c', 'j', 'o', 't', 'u'): ((' ', 'a', 'e', 'i'), 1.0),
#  ('c', 'i', 'o', 't'): (('a',), 0.75),
#  ('a', 'c', 'i', 'o', 't'): (('e',), 1.0),
#  ('a', 'c', 'i', 't', 'u'): (('o',), 1.2),
#  ('c', 'i', 'j', 'o', 't'): ((' ', 'a', 'e', 'u'), 0.75),
#  ('c', 'i', 'j', 't', 'u'): ((' ', 'a', 'e'), 1.6666666666666667),
#  ('c', 'i', 'o', 't', 'u'): (('a',), 0.75),
#  ('a', 'c', 'i', 'j', 'o', 't'): ((' ', 'e', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'o', 'u'): ((' ', 'e', 't'), 1.0),
#  ('a', 'c', 'i', 'o', 't', 'u'): ((' ',), 1.0),
#  ('a', 'c', 'j', 'o', 't', 'u'): ((' ', 'e', 'i'), 0.75),
#  ('a', 'i', 'j', 'o', 't', 'u'): (('e',), 1.0),
#  ('c', 'i', 'j', 'o', 't', 'u'): ((' ', 'a', 'e'), 1.5),
#  ('a', 'c', 'i', 't'): (('e',), 1.0),
#  ('a', 'c', 'i', 'j', 't'): ((' ', 'e', 'u'), 1.0),
#  ('a', 'i', 'j', 't', 'u'): (('e',), 1.0),
#  ('a', 'i', 'i', 'j'): (('t',), 1.0),
#  ('a', 'i', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  ('a', 'c', 'i', 'i', 'j', 'u'): ((' ', 'e', 't'), 1.0),
#  ('c', 't', 't'): (('e',), 2.5),
#  ('a', 'j', 't', 't'): (('e', 'u'), 1.0),
#  ('a', 't', 't', 'u'): (('o',), 1.5),
#  ('c', 'j', 't', 't'): ((' ', 'e', 'u'), 1.0),
#  ('c', 't', 't', 'u'): (('o',), 1.5),
#  ('c', 'j', 't', 't', 'u'): ((' ', 'e'), 1.0),
#  ('a', 'a', 'c'): (('t',), 1.0),
#  ('a', 'a', 'c', 'i'): (('t',), 2.0),
#  ('a', 'a', 'c', 't'): (('e', 'o'), 1.0),
#  ('a', 'a', 'c', 'i', 'j'): (('e', 't', 'u'), 1.0),
#  ('c', 'i', 't', 't'): (('a',), 1.6666666666666667),
#  ('j', 'n'): (('a', 'c', 'i', 'o', 't', 'u'), 1.0),
#  (' ', 'c', 'n'): (('a', 'e', 'i', 'o', 't'), 1.0),
#  (' ', 'j', 'n'): (('a', 'e', 'i', 'o', 't'), 1.0),
#  ('c', 'j', 'n'): (('a', 'i', 'o', 't', 'u'), 1.0),
#  (' ', 'a', 'j'): (('e', 'i', 't', 'u'), 3.3333333333333335),
#  ('a', 'c', 'n'): (('i',), 1.8),
#  ('a', 'j', 'n'): (('i', 't'), 1.0),
#  (' ', 'a', 'c', 'n'): (('i', 't'), 1.0),
#  (' ', 'a', 'j', 'n'): (('e', 'i', 't', 'u'), 1.0),
#  (' ', 'c', 'j', 'n'): (('a', 'e', 'i', 'o', 't', 'u'), 1.0),
#  ('a', 'c', 'j', 'n'): (('i', 'o', 't', 'u'), 1.0),
#  ('c', 'n', 'o'): ((' ', 'a', 'e', 'i', 't'), 1.0),
#  ('j', 'n', 'o'): (('a', 'c', 'i', 't', 'u'), 1.0),
#  (' ', 'c', 'n', 'o'): (('a', 'e', 'i', 't'), 1.0),
#  (' ', 'j', 'n', 'o'): (('a', 'e', 'i', 't'), 1.0),
#  ('c', 'j', 'n', 'o'): (('a', 'i', 't', 'u'), 1.0),
#  ('c', 'i', 'n'): (('a',), 1.8),
#  ('i', 'j', 'n'): (('a', 't'), 1.0),
#  (' ', 'c', 'i', 'j'): (('a', 'e', 't', 'u'), 3.3333333333333335),
#  (' ', 'c', 'i', 'n'): (('a', 't'), 1.0),
#  (' ', 'i', 'j', 'n'): (('a', 'e', 't', 'u'), 1.0),
#  ('c', 'i', 'j', 'n'): (('a', 'o', 't', 'u'), 1.0),
#  (' ', 'j', 't'): (('e', 'u'), 1.0),
#  ('c', 'n', 't'): (('a', 'i'), 2.0),
#  ('j', 'n', 't'): (('a', 'i'), 1.0),
#  (' ', 'c', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'c', 'n', 't'): (('a', 'i'), 1.0),
#  (' ', 'j', 'n', 't'): (('a', 'e', 'i', 'u'), 1.0),
#  ('c', 'j', 'n', 't'): (('a', 'i', 'o', 'u'), 1.0),
#  ('a', 'j', 'n', 'o'): (('c', 'i', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'n', 'o'): (('e', 'i', 't'), 1.0),
#  (' ', 'a', 'j', 'n', 'o'): (('e', 'i', 't'), 1.0),
#  (' ', 'c', 'j', 'n', 'o'): (('a', 'e', 'i', 't', 'u'), 1.0),
#  ('a', 'c', 'j', 'n', 'o'): (('i', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'i'): (('t',), 2.0),
#  (' ', 'a', 'i', 'j'): (('e', 't', 'u'), 2.0),
#  ('a', 'i', 'j', 'n'): (('t',), 1.0),
#  (' ', 'a', 'c', 'i', 'j'): (('e', 't', 'u'), 2.0),
#  (' ', 'a', 'c', 'i', 'n'): (('t',), 1.0),
#  (' ', 'a', 'c', 'j', 'n'): (('e', 'i', 't', 'u'), 1.0),
#  (' ', 'a', 'i', 'j', 'n'): (('e', 't', 'u'), 1.0),
#  (' ', 'c', 'i', 'j', 'n'): (('a', 'e', 't', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'n'): (('o', 't', 'u'), 1.0),
#  ('a', 'j', 'n', 't'): (('i',), 1.0),
#  (' ', 'a', 'c', 'n', 't'): (('i',), 1.0),
#  (' ', 'a', 'j', 'n', 't'): (('e', 'i', 'u'), 1.0),
#  (' ', 'c', 'j', 'n', 't'): (('a', 'e', 'i', 'u'), 1.0),
#  ('a', 'c', 'j', 'n', 't'): (('i', 'o', 'u'), 1.0),
#  ('i', 'j', 'n', 'o'): (('a', 'c', 't', 'u'), 1.0),
#  (' ', 'c', 'i', 'n', 'o'): (('a', 'e', 't'), 1.0),
#  (' ', 'i', 'j', 'n', 'o'): (('a', 'e', 't'), 1.0),
#  ('c', 'i', 'j', 'n', 'o'): (('a', 't', 'u'), 1.0),
#  ('j', 'n', 'o', 't'): (('a', 'c', 'i', 'u'), 1.0),
#  (' ', 'c', 'n', 'o', 't'): (('a', 'e', 'i'), 1.0),
#  (' ', 'j', 'n', 'o', 't'): (('a', 'e', 'i'), 1.0),
#  ('c', 'j', 'n', 'o', 't'): (('a', 'i', 'u'), 1.0),
#  ('i', 'j', 'n', 't'): (('a',), 1.0),
#  (' ', 'c', 'i', 'n', 't'): (('a',), 1.0),
#  (' ', 'i', 'j', 'n', 't'): (('a', 'e', 'u'), 1.0),
#  ('c', 'i', 'j', 'n', 't'): (('a', 'o', 'u'), 1.0),
#  ('a', 'i', 'j', 'n', 'o'): (('c', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 'o'): (('e', 't'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 'o'): (('e', 'i', 't', 'u'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 'o'): (('e', 't'), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 'o'): (('a', 'e', 't', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 'o'): (('t', 'u'), 1.0),
#  ('a', 'j', 'n', 'o', 't'): (('c', 'i', 'u'), 1.0),
#  (' ', 'a', 'c', 'n', 'o', 't'): (('e', 'i'), 1.0),
#  (' ', 'a', 'j', 'n', 'o', 't'): (('e', 'i'), 1.0),
#  (' ', 'c', 'j', 'n', 'o', 't'): (('a', 'e', 'i', 'u'), 1.0),
#  ('a', 'c', 'j', 'n', 'o', 't'): (('i', 'u'), 1.0),
#  ('a', 'i', 'j', 'n', 't'): (('e',), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n'): (('e', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 't'): (('e', 'j', 'u'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 't'): (('e', 'i', 'u'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 't'): (('e', 'u'), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 't'): (('a', 'e', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 't'): (('o', 'u'), 1.0),
#  ('i', 'j', 'n', 'o', 't'): (('a', 'c', 'u'), 1.0),
#  (' ', 'c', 'i', 'n', 'o', 't'): (('a', 'e'), 1.0),
#  (' ', 'i', 'j', 'n', 'o', 't'): (('a', 'e'), 1.0),
#  ('c', 'i', 'j', 'n', 'o', 't'): (('a', 'u'), 1.0),
#  ('a', 'i', 'j', 'n', 'o', 't'): (('c', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o'): (('e', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 'o', 't'): (('e',), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 'o', 't'): (('e', 'i', 'u'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 'o', 't'): (('e',), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 'o', 't'): (('a', 'e', 'u'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 'o', 't'): (('u',), 1.0),
#  (' ', 'c', 'i', 't'): (('a',), 1.6666666666666667),
#  (' ', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'j', 'o'): (('a', 'e', 'i', 't', 'u'), 2.0),
#  (' ', 'c', 'i', 'o'): (('a', 't'), 1.5),
#  (' ', 'c', 'j', 'o'): (('a', 'e', 'i', 't', 'u'), 2.0),
#  (' ', 'i', 'j', 'o'): (('a', 'e', 't', 'u'), 1.5),
#  (' ', 'j', 'o', 't'): (('a', 'e', 'i', 'u'), 1.0),
#  (' ', 'c', 'i', 'j', 'o'): (('a', 'e', 't', 'u'), 1.5),
#  (' ', 'a', 'j', 'o'): (('e', 'i', 't', 'u'), 1.5),
#  (' ', 'a', 'c', 'o'): (('e', 't'), 2.0),
#  (' ', 'a', 'i', 'o'): (('e', 'n', 't'), 1.3333333333333333),
#  (' ', 'a', 'c', 'i', 'o'): (('t',), 1.0),
#  (' ', 'a', 'c', 'j', 'o'): (('e', 'i', 't', 'u'), 1.5),
#  (' ', 'a', 'i', 'j', 'o'): (('e', 't', 'u'), 1.0),
#  (' ', 'a', 'j', 't'): (('e', 'i', 'u'), 1.6666666666666667),
#  (' ', 'a', 'c', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'j', 'o', 't'): (('e', 'i', 'u'), 1.5),
#  (' ', 'c', 'j', 'o', 't'): (('a', 'e', 'i', 'u'), 1.0),
#  (' ', 'c', 'i', 'j', 't'): (('a', 'e', 'u'), 1.6666666666666667),
#  (' ', 'c', 'i', 'o', 't'): (('a',), 0.75),
#  (' ', 'i', 'j', 'o', 't'): (('a', 'e', 'u'), 0.75),
#  (' ', 'a', 'c', 'i', 'j', 'o'): (('e', 't', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'o', 't'): (('e',), 1.0),
#  (' ', 'a', 'c', 'j', 'o', 't'): (('e', 'i', 'u'), 0.75),
#  (' ', 'a', 'i', 'j', 'o', 't'): (('e', 'u'), 1.0),
#  (' ', 'c', 'i', 'j', 'o', 't'): (('a', 'e', 'u'), 1.5),
#  (' ', 'a', 'c', 'i', 't'): (('e',), 1.0),
#  (' ', 'a', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'i', 'i'): (('e', 'n', 'o', 't'), 1.0),
#  (' ', 'i', 'i', 't'): (('a', 'e', 'n', 'o'), 1.0),
#  (' ', 'a', 'i', 'i', 't'): (('e', 'n', 'o'), 1.0),
#  (' ', 'a', 'c', 'i', 'i', 'j'): (('e', 't', 'u'), 1.0),
#  (' ', 'c', 't', 't'): (('e',), 2.5),
#  (' ', 'j', 't', 't'): (('e', 'u'), 1.0),
#  (' ', 'c', 'j', 't', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'c', 'u'): (('i', 't'), 3.3333333333333335),
#  (' ', 'c', 't', 'u'): (('i',), 0.75),
#  (' ', 'j', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'c', 'j', 'u'): (('e', 't'), 1.0),
#  (' ', 'a', 'c', 't', 'u'): (('i',), 1.6666666666666667),
#  (' ', 'a', 'j', 't', 'u'): (('e', 'i'), 1.6666666666666667),
#  (' ', 'c', 'j', 't', 'u'): (('e',), 1.0),
#  (' ', 'c', 'o', 'u'): (('a', 'i', 't'), 2.0),
#  (' ', 'j', 'o', 'u'): (('a', 'e', 'i', 't'), 2.0),
#  (' ', 'a', 'c', 'o', 'u'): (('i', 't'), 1.5),
#  (' ', 'a', 'j', 'o', 'u'): (('e', 'i', 't'), 1.5),
#  (' ', 'c', 'j', 'o', 'u'): (('a', 'e', 'i', 't'), 2.0),
#  (' ', 'c', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'j', 'o', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  (' ', 'a', 'c', 'j', 'o', 'u'): (('e', 'i', 't'), 1.5),
#  (' ', 'a', 'c', 'o', 't', 'u'): (('i',), 1.5),
#  (' ', 'i', 'j', 'u'): (('e', 't'), 1.0),
#  (' ', 'i', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'c', 'i', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'i', 'j', 'o', 'u'): (('a', 'e', 't'), 1.5),
#  (' ', 'a', 'i', 'u'): (('t',), 2.0),
#  (' ', 'a', 'c', 'i', 'u'): (('t',), 2.0),
#  (' ', 'a', 'i', 'j', 'u'): (('e', 't'), 2.0),
#  (' ', 'a', 'i', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'u'): (('e', 't'), 2.0),
#  (' ', 'a', 'c', 'i', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'i', 'j', 'o', 'u'): (('e', 't'), 1.0),
#  (' ', 'c', 'i', 'j', 'o', 'u'): (('a', 'e', 't'), 1.5),
#  (' ', 'o', 'u'): (('t',), 0.7272727272727273),
#  (' ', 'i', 't', 'u'): (('a',), 1.6666666666666667),
#  (' ', 'c', 'i', 't', 'u'): (('a',), 1.6666666666666667),
#  (' ', 'i', 'j', 't', 'u'): (('e',), 1.0),
#  (' ', 'i', 'o', 't', 'u'): (('a',), 0.75),
#  (' ', 'c', 'i', 'j', 't', 'u'): (('a', 'e'), 1.6666666666666667),
#  (' ', 'c', 'i', 'o', 't', 'u'): (('a',), 0.75),
#  (' ', 'c', 'j', 'o', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  (' ', 'i', 'j', 'o', 't', 'u'): (('a', 'e'), 1.5),
#  (' ', 'a', 'c', 'j', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'i', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'j', 'o', 't', 'u'): (('e', 'i'), 0.75),
#  (' ', 'a', 'c', 'i', 'j', 'o', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'o', 'u'): (('e', 't'), 1.0),
#  (' ', 'a', 'c', 'i', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'c', 'j', 'o', 't', 'u'): (('e', 'i'), 1.5),
#  (' ', 'a', 'i', 'j', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'c', 'i', 'j', 'o', 't', 'u'): (('a', 'e'), 0.75),
#  ('a', 'c', 'i', 'j', 'o', 't', 'u'): ((' ', 'e'), 1.0),
#  (' ', 'a', 'i', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 't', 'u'): (('e', 'j'), 1.0),
#  (' ', 'a', 'i', 'j', 't', 'u'): (('e',), 1.0),
#  ('a', 'c', 'i', 'j', 't', 'u'): ((' ', 'e'), 1.0),
#  (' ', 'a', 'a', 'c', 'i'): (('t',), 1.0),
#  (' ', 'a', 'a', 'i', 'j'): (('e', 't', 'u'), 1.0),
#  (' ', 'a', 'a', 'i', 'u'): (('t',), 1.0),
#  (' ', 'a', 'a', 'c', 'i', 'u'): (('t',), 1.0),
#  (' ', 'a', 'a', 'c', 'i', 't'): (('e',), 1.0),
#  (' ', 'a', 'a', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'a', 'i', 't', 'u'): (('e',), 1.0),
#  ('a', 'a', 'c', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  ('a', 'a', 'i', 'j', 't', 'u'): ((' ', 'e'), 1.0),
#  (' ', 'a', 'a', 'c', 'i', 'j', 'u'): (('t',), 1.0),
#  (' ', 'a', 'a', 'c', 'i', 't', 'u'): (('j',), 1.0),
#  (' ', 't', 't', 'u'): (('o',), 1.75),
#  (' ', 'c', 'i', 't', 't'): (('e',), 1.0),
#  (' ', 'c', 't', 't', 'u'): (('i',), 1.5),
#  (' ', 'i', 'j', 't', 't'): (('e', 'u'), 1.0),
#  (' ', 'i', 't', 't', 'u'): (('e',), 1.0),
#  (' ', 'j', 't', 't', 'u'): (('e',), 1.0),
#  ('c', 'i', 'j', 't', 't'): (('e', 'u'), 1.0),
#  ('i', 'j', 't', 't', 'u'): ((' ', 'e'), 1.0),
#  (' ', 'c', 'i', 't', 't', 'u'): (('j',), 1.0),
#  (' ', 'c', 'j', 't', 't', 'u'): (('e',), 1.0),
#  ('n', 'u'): ((' ', 'a', 'c', 'e', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'n', 'u'): (('a', 'c', 'e', 'i', 'o', 't', 'y'), 1.0),
#  ('j', 'n', 'u'): (('a', 'c', 'i', 'o', 't'), 1.0),
#  ('c', 'n', 'u'): ((' ', 'a', 'e', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'c', 'n', 'u'): (('a', 'e', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'j', 'n', 'u'): (('a', 'e', 'i', 'o', 't'), 1.0),
#  ('c', 'j', 'n', 'u'): (('a', 'i', 'o', 't'), 1.0),
#  ('a', 'n', 'u'): (('i', 't'), 1.0),
#  (' ', 'a', 'n', 'u'): (('c', 'e', 'i', 'o', 't', 'y'), 1.0),
#  ('a', 'j', 'n', 'u'): (('c', 'i', 'o', 't'), 1.0),
#  ('n', 'o', 'u'): ((' ', 'a', 'c', 'e', 'i', 't', 'y'), 1.0),
#  (' ', 'n', 'o', 'u'): (('a', 'c', 'e', 'i', 't', 'y'), 1.0),
#  ('j', 'n', 'o', 'u'): (('a', 'c', 'i', 't'), 1.0),
#  ('i', 'n', 'u'): (('a', 't'), 1.0),
#  (' ', 'i', 'n', 'u'): (('a', 'c', 'e', 'o', 't', 'y'), 1.0),
#  ('i', 'j', 'n', 'u'): (('a', 'c', 'o', 't'), 1.0),
#  ('n', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'n', 't', 'u'): (('a', 'c', 'e', 'i', 'o', 'y'), 1.0),
#  ('j', 'n', 't', 'u'): (('a', 'c', 'i', 'o'), 1.0),
#  ('a', 'c', 'n', 'u'): ((' ', 'e', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'n', 'u'): (('e', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'c', 'j', 'n', 'u'): (('a', 'e', 'i', 'o', 't'), 1.0),
#  ('a', 'c', 'j', 'n', 'u'): (('i', 'o', 't'), 1.0),
#  ('c', 'n', 'o', 'u'): ((' ', 'a', 'e', 'i', 't', 'y'), 1.0),
#  (' ', 'c', 'n', 'o', 'u'): (('a', 'e', 'i', 't', 'y'), 1.0),
#  (' ', 'j', 'n', 'o', 'u'): (('a', 'e', 'i', 't'), 1.0),
#  ('c', 'j', 'n', 'o', 'u'): (('a', 'i', 't'), 1.0),
#  ('c', 'i', 'n', 'u'): ((' ', 'a', 'e', 'o', 't', 'y'), 1.0),
#  (' ', 'c', 'i', 'n', 'u'): (('a', 'e', 'o', 't', 'y'), 1.0),
#  ('c', 'i', 'j', 'n', 'u'): (('a', 'o', 't'), 1.0),
#  ('c', 'n', 't', 'u'): ((' ', 'a', 'e', 'i', 'o', 'y'), 1.0),
#  (' ', 'c', 'n', 't', 'u'): (('a', 'e', 'i', 'o', 'y'), 1.0),
#  ('c', 'j', 'n', 't', 'u'): (('a', 'i', 'o'), 1.0),
#  ('a', 'n', 'o', 'u'): ((' ', 'c', 'e', 'i', 't', 'y'), 1.0),
#  (' ', 'a', 'n', 'o', 'u'): (('c', 'e', 'i', 't', 'y'), 1.0),
#  ('a', 'j', 'n', 'o', 'u'): (('c', 'i', 't'), 1.0),
#  ('a', 'i', 'n', 'u'): (('t',), 1.0),
#  (' ', 'a', 'i', 'n', 'u'): (('c', 'e', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'j', 'n', 'u'): (('e', 'i', 't'), 1.0),
#  (' ', 'i', 'j', 'n', 'u'): (('a', 'e', 't'), 1.0),
#  ('a', 'i', 'j', 'n', 'u'): (('c', 'o', 't'), 1.0),
#  ('a', 'n', 't', 'u'): (('i',), 1.0),
#  (' ', 'a', 'n', 't', 'u'): (('c', 'e', 'i', 'o', 'y'), 1.0),
#  (' ', 'j', 'n', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  ('a', 'j', 'n', 't', 'u'): (('c', 'i', 'o'), 1.0),
#  ('i', 'n', 'o', 'u'): ((' ', 'a', 'c', 'e', 't', 'y'), 1.0),
#  (' ', 'i', 'n', 'o', 'u'): (('a', 'c', 'e', 't', 'y'), 1.0),
#  ('i', 'j', 'n', 'o', 'u'): (('a', 'c', 't'), 1.0),
#  ('n', 'o', 't', 'u'): ((' ', 'a', 'c', 'e', 'i', 'y'), 1.0),
#  (' ', 'n', 'o', 't', 'u'): (('a', 'c', 'e', 'i', 'y'), 1.0),
#  ('j', 'n', 'o', 't', 'u'): (('a', 'c', 'i'), 1.0),
#  ('i', 'n', 't', 'u'): (('a',), 1.0),
#  (' ', 'i', 'n', 't', 'u'): (('a', 'c', 'e', 'o', 'y'), 1.0),
#  ('i', 'j', 'n', 't', 'u'): (('a', 'c', 'o'), 1.0),
#  ('a', 'c', 'n', 'o', 'u'): ((' ', 'e', 'i', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 'u'): (('e', 'i', 'o', 't'), 1.0),
#  (' ', 'a', 'c', 'n', 'o', 'u'): (('e', 'i', 't', 'y'), 1.0),
#  (' ', 'a', 'j', 'n', 'o', 'u'): (('e', 'i', 't'), 1.0),
#  (' ', 'c', 'j', 'n', 'o', 'u'): (('a', 'e', 'i', 't'), 1.0),
#  ('a', 'c', 'j', 'n', 'o', 'u'): (('i', 't'), 1.0),
#  ('a', 'c', 'i', 'n', 'u'): ((' ', 'e', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 'u'): (('e', 'o', 't', 'y'), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 'u'): (('a', 'e', 'o', 't'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 'u'): (('o', 't'), 1.0),
#  ('a', 'c', 'n', 't', 'u'): ((' ', 'e', 'i', 'o', 'y'), 1.0),
#  (' ', 'a', 'c', 'n', 't', 'u'): (('e', 'i', 'o', 'y'), 1.0),
#  (' ', 'c', 'j', 'n', 't', 'u'): (('a', 'e', 'i', 'o'), 1.0),
#  ('a', 'c', 'j', 'n', 't', 'u'): (('i', 'o'), 1.0),
#  ('c', 'i', 'n', 'o', 'u'): ((' ', 'a', 'e', 't', 'y'), 1.0),
#  (' ', 'c', 'i', 'n', 'o', 'u'): (('a', 'e', 't', 'y'), 1.0),
#  (' ', 'i', 'j', 'n', 'o', 'u'): (('a', 'e', 't'), 1.0),
#  ('c', 'i', 'j', 'n', 'o', 'u'): (('a', 't'), 1.0),
#  ('c', 'n', 'o', 't', 'u'): ((' ', 'a', 'e', 'i', 'y'), 1.0),
#  (' ', 'c', 'n', 'o', 't', 'u'): (('a', 'e', 'i', 'y'), 1.0),
#  (' ', 'j', 'n', 'o', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  ('c', 'j', 'n', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('c', 'i', 'n', 't', 'u'): ((' ', 'a', 'e', 'o', 'y'), 1.0),
#  (' ', 'c', 'i', 'n', 't', 'u'): (('a', 'e', 'o', 'y'), 1.0),
#  ('c', 'i', 'j', 'n', 't', 'u'): (('a', 'o'), 1.0),
#  ('a', 'i', 'n', 'o', 'u'): ((' ', 'c', 'e', 't', 'y'), 1.0),
#  (' ', 'a', 'i', 'n', 'o', 'u'): (('c', 'e', 't', 'y'), 1.0),
#  ('a', 'i', 'j', 'n', 'o', 'u'): (('c', 't'), 1.0),
#  ('a', 'n', 'o', 't', 'u'): ((' ', 'c', 'e', 'i', 'y'), 1.0),
#  (' ', 'a', 'n', 'o', 't', 'u'): (('c', 'e', 'i', 'y'), 1.0),
#  ('a', 'j', 'n', 'o', 't', 'u'): (('c', 'i'), 1.0),
#  ('a', 'i', 'n', 't', 'u'): (('e', 'j'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 'u'): (('e', 't'), 1.0),
#  (' ', 'a', 'i', 'n', 't', 'u'): (('c', 'e', 'o', 'y'), 1.0),
#  (' ', 'a', 'j', 'n', 't', 'u'): (('e', 'i'), 1.0),
#  (' ', 'i', 'j', 'n', 't', 'u'): (('a', 'e'), 1.0),
#  ('a', 'i', 'j', 'n', 't', 'u'): (('c', 'o'), 1.0),
#  ('i', 'n', 'o', 't', 'u'): ((' ', 'a', 'c', 'e', 'y'), 1.0),
#  (' ', 'i', 'n', 'o', 't', 'u'): (('a', 'c', 'e', 'y'), 1.0),
#  ('i', 'j', 'n', 'o', 't', 'u'): (('a', 'c'), 1.0),
#  ('a', 'c', 'i', 'n', 'o', 'u'): ((' ', 'e', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 'u'): (('e', 'o', 't'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 'o', 'u'): (('e', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 'o', 'u'): (('e', 'i', 't'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 'o', 'u'): (('e', 't'), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 'o', 'u'): (('a', 'e', 't'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 'o', 'u'): (('t',), 1.0),
#  ('a', 'c', 'n', 'o', 't', 'u'): ((' ', 'e', 'i', 'y'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 't', 'u'): (('e', 'i', 'o'), 1.0),
#  (' ', 'a', 'c', 'n', 'o', 't', 'u'): (('e', 'i', 'y'), 1.0),
#  (' ', 'a', 'j', 'n', 'o', 't', 'u'): (('e', 'i'), 1.0),
#  (' ', 'c', 'j', 'n', 'o', 't', 'u'): (('a', 'e', 'i'), 1.0),
#  ('a', 'c', 'j', 'n', 'o', 't', 'u'): (('i',), 1.0),
#  ('a', 'c', 'i', 'n', 't', 'u'): ((' ', 'e', 'o', 'y'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 't', 'u'): (('e', 'o', 'y'), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 't', 'u'): (('a', 'e', 'o'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 't', 'u'): (('o',), 1.0),
#  ('c', 'i', 'n', 'o', 't', 'u'): ((' ', 'a', 'e', 'y'), 1.0),
#  (' ', 'c', 'i', 'n', 'o', 't', 'u'): (('a', 'e', 'y'), 1.0),
#  (' ', 'i', 'j', 'n', 'o', 't', 'u'): (('a', 'e'), 1.0),
#  ('c', 'i', 'j', 'n', 'o', 't', 'u'): (('a',), 1.0),
#  ('a', 'i', 'n', 'o', 't', 'u'): ((' ', 'c', 'e', 'y'), 1.0),
#  (' ', 'a', 'i', 'n', 'o', 't', 'u'): (('c', 'e', 'y'), 1.0),
#  ('a', 'i', 'j', 'n', 'o', 't', 'u'): (('c',), 1.0),
#  ('a', 'c', 'i', 'n', 'o', 't', 'u'): ((' ', 'e', 'y'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 'u'): (('e', 't'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 't', 'u'): (('e', 'o'), 1.0),
#  (' ', 'a', 'c', 'i', 'n', 'o', 't', 'u'): (('e', 'y'), 1.0),
#  (' ', 'a', 'c', 'j', 'n', 'o', 't', 'u'): (('e', 'i'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'c', 'i', 'j', 'n', 'o', 't', 'u'): (('a', 'e'), 1.0),
#  ('a', 'c', 'i', 'j', 'n', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'i', 'i', 'j', 'u'): (('c', 'e', 't'), 1.0),
#  ('e', 'j', 't'): (('i',), 0.75),
#  (' ', 'e', 'i', 'j'): (('t', 'u'), 1.0),
#  (' ', 'e', 'j', 't'): (('u',), 1.0),
#  ('e', 'i', 'j', 't'): (('a',), 1.6666666666666667),
#  ('e', 'j', 'o'): (('a', 'i', 't'), 2.0),
#  (' ', 'e', 'j', 'o'): (('a', 'i', 't', 'u'), 2.0),
#  ('e', 'i', 'j', 'o'): (('a', 't'), 1.5),
#  ('e', 'j', 'o', 't'): (('a', 'i'), 1.0),
#  (' ', 'e', 'i', 'j', 'o'): (('a', 't', 'u'), 1.5),
#  ('a', 'e', 'j'): (('i', 't'), 3.3333333333333335),
#  ('a', 'e', 'j', 'o'): (('i', 't'), 1.5),
#  ('a', 'e', 'i', 'j'): (('t',), 2.0),
#  (' ', 'a', 'e', 'i', 'j'): (('t', 'u'), 2.0),
#  (' ', 'a', 'e', 'i', 'o'): (('n', 't'), 1.3333333333333333),
#  (' ', 'a', 'e', 'j', 'o'): (('i', 't', 'u'), 1.5),
#  ('a', 'e', 'i', 'j', 'o'): (('t',), 1.0),
#  ('a', 'e', 'j', 't'): (('i',), 1.6666666666666667),
#  (' ', 'a', 'e', 'j', 't'): (('i', 'u'), 1.6666666666666667),
#  (' ', 'e', 'j', 'o', 't'): (('a', 'i', 'u'), 1.0),
#  ('a', 'e', 'j', 'o', 't'): (('i',), 1.5),
#  (' ', 'e', 'i', 'j', 't'): (('u',), 1.0),
#  ('e', 'i', 'j', 'o', 't'): (('a',), 0.75),
#  (' ', 'a', 'e', 'i', 'j', 'o'): (('t', 'u'), 1.0),
#  (' ', 'a', 'e', 'j', 'o', 't'): (('i', 'u'), 0.75),
#  (' ', 'e', 'i', 'j', 'o', 't'): (('a', 'u'), 1.5),
#  ('a', 'e', 'i', 'j', 'o', 't'): (('u',), 1.0),
#  ('a', 'e', 'i', 'j', 't'): (('u',), 1.0),
#  (' ', 'a', 'e', 'i', 'i'): (('n', 'o', 't'), 1.0),
#  (' ', 'e', 'i', 'i', 't'): (('a', 'n', 'o'), 1.0),
#  (' ', 'a', 'e', 'i', 'i', 'j'): (('c', 't', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'i', 't'): (('n', 'o'), 1.0),
#  ('e', 'j', 't', 't'): (('i',), 1.5),
#  (' ', 'e', 'j', 't', 't'): (('u',), 1.0),
#  ('c', 'e', 'n'): ((' ', 'a', 'i', 'o', 't'), 1.0),
#  ('e', 'j', 'n'): ((' ', 'a', 'i', 'o', 't'), 1.0),
#  (' ', 'c', 'e', 'n'): (('a', 'i', 'o', 't'), 1.0),
#  (' ', 'e', 'j', 'n'): (('a', 'i', 'o', 't'), 1.0),
#  ('c', 'e', 'j', 'n'): (('a', 'i', 'o', 't', 'u'), 1.0),
#  ('c', 'e', 'i', 'j'): ((' ', 'a', 't', 'u'), 3.3333333333333335),
#  ('c', 'e', 'i', 'n'): (('a', 't'), 1.0),
#  ('e', 'i', 'j', 'n'): (('a', 't'), 1.0),
#  (' ', 'c', 'e', 'i', 'n'): (('a', 'o', 't'), 1.0),
#  (' ', 'c', 'e', 'j', 'n'): (('a', 'i', 'o', 't', 'u'), 1.0),
#  (' ', 'e', 'i', 'j', 'n'): (('a', 'o', 't'), 1.0),
#  ('c', 'e', 'i', 'j', 'n'): ((' ', 'a', 't', 'u'), 1.0),
#  ('c', 'e', 'n', 'o'): ((' ', 'a', 'i', 't'), 1.0),
#  ('e', 'j', 'n', 'o'): ((' ', 'a', 'i', 't'), 1.0),
#  (' ', 'c', 'e', 'n', 'o'): (('a', 'i', 't'), 1.0),
#  (' ', 'e', 'j', 'n', 'o'): (('a', 'i', 't'), 1.0),
#  ('c', 'e', 'j', 'n', 'o'): (('a', 'i', 't', 'u'), 1.0),
#  ('a', 'c', 'e', 'n'): (('i', 't'), 1.0),
#  ('a', 'e', 'j', 'n'): (('i', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'j'): (('t', 'u'), 1.0),
#  (' ', 'a', 'c', 'e', 'n'): (('i', 'o', 't'), 1.0),
#  (' ', 'a', 'e', 'j', 'n'): (('i', 'o', 't'), 1.0),
#  ('a', 'c', 'e', 'j', 'n'): ((' ', 'i', 't', 'u'), 1.0),
#  ('c', 'e', 'j', 't'): ((' ', 'u'), 1.0),
#  ('c', 'e', 'n', 't'): (('a', 'i'), 1.0),
#  ('e', 'j', 'n', 't'): (('a', 'i'), 1.0),
#  (' ', 'c', 'e', 'j', 't'): (('u',), 1.0),
#  (' ', 'c', 'e', 'n', 't'): (('a', 'i', 'o'), 1.0),
#  (' ', 'e', 'j', 'n', 't'): (('a', 'i', 'o'), 1.0),
#  ('c', 'e', 'j', 'n', 't'): ((' ', 'a', 'i', 'u'), 1.0),
#  ('c', 'e', 'i', 'n', 'o'): ((' ', 'a', 't'), 1.0),
#  ('e', 'i', 'j', 'n', 'o'): ((' ', 'a', 't'), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 'o'): (('a', 't'), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 'o'): (('a', 'i', 't', 'u'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 'o'): (('a', 't'), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 'o'): (('a', 't', 'u'), 1.0),
#  ('a', 'c', 'e', 'i'): (('t',), 2.0),
#  (' ', 'a', 'c', 'e', 'i'): (('t',), 2.0),
#  ('a', 'c', 'e', 'i', 'j'): ((' ', 't', 'u'), 2.0),
#  ('a', 'c', 'e', 'i', 'n'): (('t',), 1.0),
#  ('a', 'e', 'i', 'j', 'n'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j'): (('t', 'u'), 2.0),
#  (' ', 'a', 'c', 'e', 'i', 'n'): (('o', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n'): (('i', 't', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n'): (('o', 't'), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n'): (('a', 't', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n'): ((' ', 't', 'u'), 1.0),
#  ('c', 'e', 'i', 'n', 't'): (('a',), 1.0),
#  ('e', 'i', 'j', 'n', 't'): (('a',), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 't'): (('a', 'o'), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 't'): (('a', 'i', 'u'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 't'): (('a', 'o'), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 't'): ((' ', 'a', 'u'), 1.0),
#  ('a', 'c', 'e', 'n', 'o'): ((' ', 'i', 't'), 1.0),
#  ('a', 'e', 'j', 'n', 'o'): ((' ', 'i', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 'o'): (('i', 't'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 'o'): (('i', 't'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 'o'): (('i', 't', 'u'), 1.0),
#  ('c', 'e', 'n', 'o', 't'): ((' ', 'a', 'i'), 1.0),
#  ('e', 'j', 'n', 'o', 't'): ((' ', 'a', 'i'), 1.0),
#  (' ', 'c', 'e', 'n', 'o', 't'): (('a', 'i'), 1.0),
#  (' ', 'e', 'j', 'n', 'o', 't'): (('a', 'i'), 1.0),
#  ('c', 'e', 'j', 'n', 'o', 't'): (('a', 'i', 'u'), 1.0),
#  ('a', 'c', 'e', 'n', 't'): (('i',), 1.0),
#  ('a', 'e', 'j', 'n', 't'): (('i',), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 't'): (('i', 'o'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 't'): (('i', 'o'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 't'): ((' ', 'i', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 'o'): ((' ', 't'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 'o'): ((' ', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 'o'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o'): (('i', 't', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o'): (('t',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o'): (('a', 't', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o'): (('t', 'u'), 1.0),
#  ('c', 'e', 'i', 'n', 'o', 't'): ((' ', 'a'), 1.0),
#  ('e', 'i', 'j', 'n', 'o', 't'): ((' ', 'a'), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 'o', 't'): (('a',), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 'o', 't'): (('a', 'i', 'u'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 'o', 't'): (('a',), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 'o', 't'): (('a', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 't'): ((' ', 'j', 'u'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n'): (('t', 'u'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 't'): (('o',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 't'): (('i', 'u'), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 't'): (('o',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 't'): (('a', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 't'): ((' ', 'u'), 1.0),
#  ('a', 'c', 'e', 'n', 'o', 't'): ((' ', 'i'), 1.0),
#  ('a', 'e', 'j', 'n', 'o', 't'): ((' ', 'i'), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 'o', 't'): (('i',), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 'o', 't'): (('i',), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 'o', 't'): (('i', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 'o', 't'): ((' ',), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 'o', 't'): ((' ',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o'): (('t', 'u'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 'o', 't'): (('u', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 't'): (('i', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 't'): (('u',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 't'): (('a', 'u'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 't'): (('u',), 1.0),
#  ('a', 'c', 'e', 'j', 't'): ((' ', 'u'), 1.0),
#  ('c', 'e', 'j', 'o'): ((' ', 'a', 'i', 't', 'u'), 2.0),
#  (' ', 'c', 'e', 'j', 'o'): (('a', 'i', 't', 'u'), 2.0),
#  ('a', 'c', 'e', 'j', 'o'): ((' ', 'i', 't', 'u'), 1.5),
#  ('c', 'e', 'j', 'o', 't'): ((' ', 'a', 'i', 'u'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'o'): (('i', 't', 'u'), 1.5),
#  ('c', 'e', 'i', 'o'): (('a', 't'), 1.5),
#  (' ', 'c', 'e', 'i', 'o'): (('a', 't'), 1.5),
#  ('c', 'e', 'i', 'j', 'o'): ((' ', 'a', 't', 'u'), 1.5),
#  ('a', 'c', 'e', 'i', 'o'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'o'): (('t',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'o'): (('a', 't', 'u'), 1.5),
#  ('a', 'c', 'e', 'i', 'j', 'o'): ((' ', 't', 'u'), 1.0),
#  ('c', 'e'): ((), 1.2),
#  (' ', 'c', 'e'): ((), 1.2),
#  ('c', 'e', 'o'): ((), 1.0909090909090908),
#  (' ', 'c', 'e', 'o'): (('a', 't'), 1.0909090909090908),
#  ('c', 'e', 'i', 't'): (('a',), 1.6666666666666667),
#  (' ', 'c', 'e', 'i', 't'): (('a',), 1.6666666666666667),
#  ('c', 'e', 'i', 'j', 't'): ((' ', 'a', 'u'), 1.6666666666666667),
#  ('c', 'e', 'i', 'o', 't'): (('a',), 0.75),
#  (' ', 'c', 'e', 'i', 'j', 't'): (('a', 'u'), 1.6666666666666667),
#  (' ', 'c', 'e', 'i', 'o', 't'): (('a',), 0.75),
#  (' ', 'c', 'e', 'j', 'o', 't'): (('a', 'i', 'u'), 1.0),
#  ('c', 'e', 'i', 'j', 'o', 't'): ((' ', 'a', 'u'), 1.5),
#  (' ', 'a', 'c', 'e', 'j', 't'): (('u',), 1.0),
#  ('a', 'c', 'e', 'i', 'o', 't'): ((' ',), 1.0),
#  ('a', 'c', 'e', 'j', 'o', 't'): ((' ', 'i', 'u'), 0.75),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o'): (('t', 'u'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'o', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'o', 't'): (('i', 'u'), 1.5),
#  (' ', 'a', 'e', 'i', 'j', 'o', 't'): (('u',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'o', 't'): (('a', 'u'), 0.75),
#  ('a', 'c', 'e', 'i', 'j', 'o', 't'): ((' ', 'u'), 1.0),
#  ('a', 'c', 'e'): ((), 1.0909090909090908),
#  (' ', 'a', 'c', 'e'): ((), 1.0909090909090908),
#  ('a', 'c', 'e', 'i', 't'): ((' ',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 't'): (('j', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 't'): (('u',), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 't'): ((' ', 'u'), 1.0),
#  ('a', 'a', 'c', 'e', 'i'): (('t',), 1.0),
#  ('a', 'a', 'e', 'i', 'j'): (('t',), 1.0),
#  (' ', 'a', 'a', 'c', 'e', 'i'): (('t',), 1.0),
#  ('a', 'a', 'c', 'e', 'i', 't'): ((' ',), 1.0),
#  ('a', 'a', 'e', 'i', 'j', 't'): ((' ', 'u'), 1.0),
#  (' ', 'a', 'a', 'c', 'e', 'i', 'j'): (('t',), 1.0),
#  (' ', 'a', 'a', 'c', 'e', 'i', 't'): (('j',), 1.0),
#  (' ', 'e', 'i', 't', 't'): (('a',), 1.6666666666666667),
#  ('c', 'e', 'i', 't', 't'): ((' ',), 1.0),
#  ('c', 'e', 'j', 't', 't'): ((' ', 'u'), 1.0),
#  ('e', 'i', 'j', 't', 't'): ((' ', 'u'), 1.0),
#  (' ', 'c', 'e', 'i', 't', 't'): (('j',), 1.0),
#  (' ', 'c', 'e', 'j', 't', 't'): (('u',), 1.0),
#  ('a', 'c', 'e', 'i', 'i', 'j'): ((' ', 't', 'u'), 1.0),
#  ('a', 'c', 'e', 'u'): ((' ', 'i', 'o', 't'), 2.0),
#  ('a', 'e', 't', 'u'): (('o',), 1.5),
#  ('c', 'e', 't', 'u'): ((' ',), 1.0),
#  ('e', 'j', 't', 'u'): (('a',), 0.75),
#  ('a', 'c', 'e', 'j', 'u'): ((' ', 't'), 1.0),
#  ('a', 'c', 'e', 't', 'u'): ((' ', 'i', 'o'), 1.0),
#  ('a', 'e', 'j', 't', 'u'): (('i',), 1.6666666666666667),
#  ('c', 'e', 'j', 't', 'u'): ((' ',), 1.0),
#  ('c', 'e', 'o', 'u'): ((' ', 't'), 1.0),
#  ('e', 'j', 'o', 'u'): (('a', 'i', 't'), 2.0),
#  ('a', 'c', 'e', 'o', 'u'): ((' ', 'i', 't'), 1.5),
#  ('a', 'e', 'j', 'o', 'u'): (('i', 't'), 1.5),
#  ('c', 'e', 'j', 'o', 'u'): ((' ', 'a', 'i', 't'), 2.0),
#  ('e', 'o', 'u'): (('t',), 1.4285714285714286),
#  ('c', 'e', 'o', 't', 'u'): ((' ',), 1.0),
#  ('e', 'j', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('a', 'c', 'e', 'j', 'o', 'u'): ((' ', 'i', 't'), 1.5),
#  ('a', 'c', 'e', 'o', 't', 'u'): ((' ', 'i'), 1.5),
#  ('e', 'i', 'j', 'u'): (('a', 't'), 3.3333333333333335),
#  ('e', 'i', 'o', 'u'): ((' ', 'a', 't'), 1.5),
#  ('c', 'e', 'i', 'o', 'u'): ((' ', 'a', 't'), 1.5),
#  ('e', 'i', 'j', 'o', 'u'): (('a', 't'), 1.5),
#  ('a', 'e', 'i', 'u'): ((' ', 't'), 2.0),
#  ('a', 'c', 'e', 'i', 'u'): ((' ', 'o', 't'), 1.2),
#  ('a', 'e', 'i', 'j', 'u'): (('t',), 2.0),
#  ('a', 'e', 'i', 'o', 'u'): ((' ', 't'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'u'): ((' ', 't'), 2.0),
#  ('a', 'c', 'e', 'i', 'o', 'u'): ((' ', 't'), 1.0),
#  ('a', 'e', 'i', 'j', 'o', 'u'): (('t',), 1.0),
#  ('c', 'e', 'i', 'j', 'o', 'u'): ((' ', 'a', 't'), 1.5),
#  ('e', 'i', 't', 'u'): ((' ',), 1.0),
#  ('e', 'o', 't', 'u'): ((' ',), 1.4),
#  ('c', 'e', 'i', 't', 'u'): ((' ', 'a', 'o'), 1.0),
#  ('e', 'i', 'j', 't', 'u'): (('a',), 1.6666666666666667),
#  ('e', 'i', 'o', 't', 'u'): ((' ', 'a'), 0.75),
#  ('c', 'e', 'i', 'j', 't', 'u'): ((' ', 'a'), 1.6666666666666667),
#  ('c', 'e', 'i', 'o', 't', 'u'): ((' ', 'a'), 0.75),
#  ('c', 'e', 'j', 'o', 't', 'u'): ((' ', 'a', 'i'), 1.0),
#  ('e', 'i', 'j', 'o', 't', 'u'): (('a',), 1.5),
#  ('a', 'c', 'e', 'j', 't', 'u'): ((' ',), 1.0),
#  ('a', 'e', 'i', 'o', 't', 'u'): ((' ',), 1.0),
#  ('a', 'e', 'j', 'o', 't', 'u'): (('i',), 0.75),
#  ('a', 'c', 'e', 'i', 'j', 'o', 'u'): ((' ', 't'), 1.0),
#  ('a', 'c', 'e', 'i', 'o', 't', 'u'): ((' ',), 1.0),
#  ('a', 'c', 'e', 'j', 'o', 't', 'u'): ((' ', 'i'), 1.5),
#  ('a', 'e', 'i', 'j', 'o', 't', 'u'): ((' ',), 1.0),
#  ('c', 'e', 'i', 'j', 'o', 't', 'u'): ((' ', 'a'), 0.75),
#  ('a', 'e', 'i', 't', 'u'): ((' ',), 1.0),
#  ('a', 'c', 'e', 'i', 't', 'u'): ((' ', 'j'), 1.0),
#  ('a', 'e', 'i', 'j', 't', 'u'): ((' ',), 1.0),
#  ('a', 'a', 'e', 'i', 'u'): ((' ', 't'), 1.0),
#  ('a', 'a', 'c', 'e', 'i', 'u'): (('t',), 1.0),
#  ('a', 'a', 'e', 'i', 't', 'u'): ((' ',), 1.0),
#  ('a', 'a', 'c', 'e', 'i', 'j', 'u'): (('t',), 1.0),
#  ('a', 'a', 'c', 'e', 'i', 't', 'u'): (('j',), 1.0),
#  ('c', 'e', 't', 't', 'u'): ((' ',), 1.0),
#  ('e', 'i', 't', 't', 'u'): ((' ',), 1.0),
#  ('e', 'j', 't', 't', 'u'): (('a',), 1.5),
#  ('c', 'e', 'i', 't', 't', 'u'): (('j',), 1.0),
#  ('c', 'e', 'j', 't', 't', 'u'): ((' ',), 1.0),
#  ('e', 'n', 'u'): ((' ', 'a', 'c', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'e', 'n', 'u'): (('a', 'c', 'i', 'o', 't', 'y'), 1.0),
#  ('c', 'e', 'n', 'u'): ((' ', 'a', 'i', 'o', 't', 'y'), 1.0),
#  ('e', 'j', 'n', 'u'): (('a', 'c', 'i', 'o', 't'), 1.0),
#  (' ', 'c', 'e', 'n', 'u'): (('a', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'e', 'j', 'n', 'u'): (('a', 'i', 'o', 't'), 1.0),
#  ('c', 'e', 'j', 'n', 'u'): (('a', 'i', 'o', 't'), 1.0),
#  ('a', 'e', 'n', 'u'): ((' ', 'c', 'i', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'u'): (('i', 'o', 't'), 2.0),
#  (' ', 'a', 'e', 'j', 'u'): (('i', 't'), 3.3333333333333335),
#  (' ', 'a', 'e', 'n', 'u'): (('c', 'i', 'o', 't', 'y'), 1.0),
#  ('a', 'c', 'e', 'n', 'u'): ((' ', 'i', 'o', 't', 'y'), 1.0),
#  ('a', 'e', 'j', 'n', 'u'): (('i', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 'u'): (('i', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 'u'): (('i', 't'), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 'u'): (('a', 'i', 'o', 't'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 'u'): (('i', 'o', 't'), 1.0),
#  ('e', 'n', 'o', 'u'): ((' ', 'a', 'c', 'i', 't', 'y'), 1.0),
#  (' ', 'e', 'n', 'o', 'u'): (('a', 'c', 'i', 't', 'y'), 1.0),
#  ('c', 'e', 'n', 'o', 'u'): ((' ', 'a', 'i', 't', 'y'), 1.0),
#  ('e', 'j', 'n', 'o', 'u'): (('a', 'c', 'i', 't'), 1.0),
#  (' ', 'c', 'e', 'n', 'o', 'u'): (('a', 'i', 't', 'y'), 1.0),
#  (' ', 'e', 'j', 'n', 'o', 'u'): (('a', 'i', 't'), 1.0),
#  ('c', 'e', 'j', 'n', 'o', 'u'): (('a', 'i', 't'), 1.0),
#  ('e', 'i', 'n', 'u'): ((' ', 'a', 'c', 'o', 't', 'y'), 1.0),
#  (' ', 'c', 'e', 'i', 'u'): (('a', 'o', 't'), 2.0),
#  (' ', 'e', 'i', 'n', 'u'): (('a', 'c', 'o', 't', 'y'), 1.0),
#  ('c', 'e', 'i', 'n', 'u'): ((' ', 'a', 'o', 't', 'y'), 1.0),
#  ('e', 'i', 'j', 'n', 'u'): (('a', 't'), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'u'): (('a', 't'), 3.3333333333333335),
#  (' ', 'c', 'e', 'i', 'n', 'u'): (('a', 'o', 't', 'y'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 'u'): (('a', 't'), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 'u'): (('a', 'o', 't'), 1.0),
#  ('e', 'n', 't', 'u'): ((' ', 'a', 'c', 'i', 'o', 'y'), 1.0),
#  (' ', 'c', 'e', 't', 'u'): (('o',), 0.75),
#  (' ', 'e', 'j', 't', 'u'): (('i',), 0.75),
#  (' ', 'e', 'n', 't', 'u'): (('a', 'c', 'i', 'o', 'y'), 1.0),
#  ('c', 'e', 'n', 't', 'u'): ((' ', 'a', 'i', 'o', 'y'), 1.0),
#  ('e', 'j', 'n', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'c', 'e', 'j', 't', 'u'): (('a',), 0.75),
#  (' ', 'c', 'e', 'n', 't', 'u'): (('a', 'i', 'o', 'y'), 1.0),
#  (' ', 'e', 'j', 'n', 't', 'u'): (('a', 'i'), 1.0),
#  ('c', 'e', 'j', 'n', 't', 'u'): (('a', 'i', 'o'), 1.0),
#  ('a', 'e', 'n', 'o', 'u'): ((' ', 'c', 'i', 't', 'y'), 1.0),
#  (' ', 'a', 'e', 'n', 'o', 'u'): (('c', 'i', 't', 'y'), 1.0),
#  ('a', 'c', 'e', 'n', 'o', 'u'): ((' ', 'i', 't', 'y'), 1.0),
#  ('a', 'e', 'j', 'n', 'o', 'u'): (('c', 'i', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 'o', 'u'): (('i', 't', 'y'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 'o', 'u'): (('i', 't'), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 'o', 'u'): (('a', 'i', 't'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 'o', 'u'): (('i', 't'), 1.0),
#  (' ', 'a', 'e', 'i', 'u'): (('t',), 2.0),
#  ('a', 'e', 'i', 'n', 'u'): ((' ', 'c', 'o', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'u'): (('o', 't'), 1.2),
#  (' ', 'a', 'e', 'i', 'j', 'u'): (('t',), 2.0),
#  (' ', 'a', 'e', 'i', 'n', 'u'): (('c', 'o', 't', 'y'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 'u'): ((' ', 'o', 't', 'y'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'u'): (('t',), 2.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 'u'): (('o', 't', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 'u'): (('i', 't'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 'u'): (('t',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 'u'): (('a', 't'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 'u'): (('o', 't'), 1.0),
#  ('a', 'e', 'n', 't', 'u'): ((' ', 'c', 'i', 'o', 'y'), 1.0),
#  (' ', 'a', 'e', 'n', 't', 'u'): (('c', 'i', 'o', 'y'), 1.0),
#  ('a', 'c', 'e', 'n', 't', 'u'): ((' ', 'i', 'o', 'y'), 1.0),
#  ('a', 'e', 'j', 'n', 't', 'u'): (('i',), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 't', 'u'): (('i', 'o', 'y'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 't', 'u'): (('i',), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 't', 'u'): (('a', 'i'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 't', 'u'): (('i', 'o'), 1.0),
#  ('e', 'i', 'n', 'o', 'u'): ((' ', 'a', 'c', 't', 'y'), 1.0),
#  (' ', 'e', 'i', 'n', 'o', 'u'): (('a', 'c', 't', 'y'), 1.0),
#  ('c', 'e', 'i', 'n', 'o', 'u'): ((' ', 'a', 't', 'y'), 1.0),
#  ('e', 'i', 'j', 'n', 'o', 'u'): (('a', 'c', 't'), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 'o', 'u'): (('a', 't', 'y'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 'o', 'u'): (('a', 't'), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 'o', 'u'): (('a', 't'), 1.0),
#  ('e', 'n', 'o', 't', 'u'): ((' ', 'a', 'c', 'i', 'y'), 1.0),
#  (' ', 'e', 'n', 'o', 't', 'u'): (('a', 'c', 'i', 'y'), 1.0),
#  ('c', 'e', 'n', 'o', 't', 'u'): ((' ', 'a', 'i', 'y'), 1.0),
#  ('e', 'j', 'n', 'o', 't', 'u'): (('a', 'c', 'i'), 1.0),
#  (' ', 'c', 'e', 'n', 'o', 't', 'u'): (('a', 'i', 'y'), 1.0),
#  (' ', 'e', 'j', 'n', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('c', 'e', 'j', 'n', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('e', 'i', 'n', 't', 'u'): ((' ', 'a', 'c', 'o', 'y'), 1.0),
#  (' ', 'e', 'i', 'n', 't', 'u'): (('a', 'c', 'o', 'y'), 1.0),
#  ('c', 'e', 'i', 'n', 't', 'u'): ((' ', 'a', 'o', 'y'), 1.0),
#  ('e', 'i', 'j', 'n', 't', 'u'): (('a',), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 't', 'u'): (('a', 'o', 'y'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 't', 'u'): (('a',), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 't', 'u'): (('a', 'o'), 1.0),
#  ('a', 'e', 'i', 'n', 'o', 'u'): ((' ', 'c', 't', 'y'), 1.0),
#  (' ', 'a', 'e', 'i', 'n', 'o', 'u'): (('c', 't', 'y'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 'o', 'u'): ((' ', 't', 'y'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 'o', 'u'): (('c', 't'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 'o', 'u'): (('t', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 'u'): (('i', 't'), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 'u'): (('t',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): (('a', 't'), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): (('t',), 1.0),
#  ('a', 'e', 'n', 'o', 't', 'u'): ((' ', 'c', 'i', 'y'), 1.0),
#  (' ', 'a', 'e', 'n', 'o', 't', 'u'): (('c', 'i', 'y'), 1.0),
#  ('a', 'c', 'e', 'n', 'o', 't', 'u'): ((' ', 'i', 'y'), 1.0),
#  ('a', 'e', 'j', 'n', 'o', 't', 'u'): (('c', 'i'), 1.0),
#  (' ', 'a', 'c', 'e', 'n', 'o', 't', 'u'): (('i', 'y'), 1.0),
#  (' ', 'a', 'e', 'j', 'n', 'o', 't', 'u'): (('i',), 1.0),
#  (' ', 'c', 'e', 'j', 'n', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  ('a', 'c', 'e', 'j', 'n', 'o', 't', 'u'): (('i',), 1.0),
#  ('a', 'e', 'i', 'n', 't', 'u'): ((' ', 'c', 'o', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 't', 'u'): (('o',), 1.2),
#  (' ', 'a', 'e', 'i', 'n', 't', 'u'): (('c', 'o', 'y'), 1.0),
#  (' ', 'a', 'i', 'j', 'n', 't', 'u'): (('e',), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 't', 'u'): ((' ', 'o', 'y'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 't', 'u'): ((' ',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 't', 'u'): (('o', 'y'), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 't', 'u'): (('i',), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 't', 'u'): (('c',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 't', 'u'): (('a',), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 't', 'u'): (('o',), 1.0),
#  ('e', 'i', 'n', 'o', 't', 'u'): ((' ', 'a', 'c', 'y'), 1.0),
#  (' ', 'e', 'i', 'n', 'o', 't', 'u'): (('a', 'c', 'y'), 1.0),
#  ('c', 'e', 'i', 'n', 'o', 't', 'u'): ((' ', 'a', 'y'), 1.0),
#  ('e', 'i', 'j', 'n', 'o', 't', 'u'): (('a', 'c'), 1.0),
#  (' ', 'c', 'e', 'i', 'n', 'o', 't', 'u'): (('a', 'y'), 1.0),
#  (' ', 'e', 'i', 'j', 'n', 'o', 't', 'u'): (('a',), 1.0),
#  ('c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): (('a',), 1.0),
#  ('a', 'e', 'i', 'n', 'o', 't', 'u'): ((' ', 'c', 'y'), 1.0),
#  (' ', 'a', 'e', 'i', 'n', 'o', 't', 'u'): (('c', 'y'), 1.0),
#  ('a', 'c', 'e', 'i', 'n', 'o', 't', 'u'): ((' ', 'y'), 1.0),
#  ('a', 'e', 'i', 'j', 'n', 'o', 't', 'u'): (('c',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'n', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'n', 'o', 't', 'u'): (('y',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'n', 'o', 't', 'u'): (('i',), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 'n', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'n', 'o', 't', 'u'): (('c',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): (('a',), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 'n', 'o', 't', 'u'): ((' ',), 1.0),
#  (' ', 'e', 'u'): (('o', 't'), 2.3333333333333335),
#  (' ', 'e', 't', 'u'): (('o',), 1.75),
#  (' ', 'e', 'i', 't', 'u'): (('a',), 1.6666666666666667),
#  (' ', 'c', 'e', 'i', 't', 'u'): (('a', 'o'), 1.0),
#  (' ', 'e', 'i', 'j', 't', 'u'): (('a',), 1.6666666666666667),
#  (' ', 'e', 'j', 'o', 'u'): (('a', 'i', 't'), 2.0),
#  (' ', 'e', 'i', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'c', 'e', 'i', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'c', 'e', 'j', 'o', 'u'): (('a', 'i', 't'), 2.0),
#  (' ', 'e', 'i', 'j', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'c', 'e', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'e', 'j', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'o', 'u'): (('a', 't'), 1.5),
#  (' ', 'a', 'c', 'e', 'o', 'u'): (('i', 't'), 1.5),
#  (' ', 'a', 'e', 'j', 'o', 'u'): (('i', 't'), 1.5),
#  (' ', 'a', 'e', 'i', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'o', 'u'): (('i', 't'), 1.5),
#  (' ', 'a', 'e', 'i', 'j', 'o', 'u'): (('t',), 1.0),
#  (' ', 'e', 'o', 'u'): (('t',), 1.2727272727272727),
#  (' ', 'a', 'c', 'e', 't', 'u'): (('i', 'o'), 1.0),
#  (' ', 'a', 'e', 'j', 't', 'u'): (('i',), 1.6666666666666667),
#  (' ', 'a', 'c', 'e', 'j', 't', 'u'): (('i',), 1.6666666666666667),
#  (' ', 'a', 'c', 'e', 'o', 't', 'u'): (('i',), 0.75),
#  (' ', 'a', 'e', 'j', 'o', 't', 'u'): (('i',), 1.5),
#  (' ', 'c', 'e', 'j', 'o', 't', 'u'): (('a', 'i'), 1.0),
#  (' ', 'e', 'i', 'o', 't', 'u'): (('a',), 0.75),
#  (' ', 'a', 'e', 'i', 'o', 't', 'u'): (('c',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 't', 'u'): (('a',), 1.6666666666666667),
#  (' ', 'c', 'e', 'i', 'o', 't', 'u'): (('a',), 0.75),
#  (' ', 'e', 'i', 'j', 'o', 't', 'u'): (('a',), 0.75),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 'o', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'o', 't', 'u'): (('j',), 1.0),
#  (' ', 'a', 'c', 'e', 'j', 'o', 't', 'u'): (('i',), 0.75),
#  (' ', 'a', 'c', 'i', 'j', 'o', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 'o', 't', 'u'): (('c',), 1.0),
#  (' ', 'c', 'e', 'i', 'j', 'o', 't', 'u'): (('a',), 1.5),
#  ('a', 'c', 'e', 'i', 'j', 'o', 't', 'u'): ((' ',), 1.0),
#  (' ', 'a', 'e', 'i', 't', 'u'): (('j',), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'j', 't'): (('u',), 1.0),
#  (' ', 'a', 'c', 'i', 'j', 't', 'u'): (('e',), 1.0),
#  (' ', 'a', 'e', 'i', 'j', 't', 'u'): (('c',), 1.0),
#  ('a', 'c', 'e', 'i', 'j', 't', 'u'): ((' ',), 1.0),
#  ('a', 'e', 'i', 'i', 'j', 'u'): (('t',), 1.0),
#  (' ', 'a', 'c', 'i', 'i', 'j', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'e', 'i', 'i', 'j', 't'): (('c', 'u'), 1.0),
#  (' ', 'a', 'i', 'i', 'j', 't', 'u'): (('c', 'e'), 1.0),
#  ('a', 'c', 'e', 'i', 'i', 'j', 't'): ((' ', 'u'), 1.0),
#  ('a', 'c', 'i', 'i', 'j', 't', 'u'): ((' ', 'e'), 1.0),
#  ('a', 'e', 'i', 'i', 'j', 't', 'u'): ((' ', 'c'), 1.0),
#  (' ', 'a', 'c', 'e', 'i', 'i', 'j', 'u'): (('t',), 1.0),
#  (' ', 'e', 't', 't', 'u'): (('o',), 1.5),
#  ('a', 'e', 't', 't', 'u'): (('o',), 1.3333333333333333),
#  (' ', 'a', 'c', 'j', 't', 't'): (('e', 'u'), 1.0),
#  (' ', 'a', 'e', 'j', 't', 't'): (('c', 'u'), 1.0),
#  (' ', 'a', 'e', 't', 't', 'u'): (('o',), 1.3333333333333333),
#  (' ', 'a', 'j', 't', 't', 'u'): (('c', 'e'), 1.0),
#  (' ', 'c', 'e', 't', 't', 'u'): (('o',), 1.5),
#  (' ', 'e', 'j', 't', 't', 'u'): (('i',), 1.5),
#  ('a', 'c', 'e', 'j', 't', 't'): ((' ', 'u'), 1.0),
#  ('a', 'c', 'j', 't', 't', 'u'): ((' ', 'e'), 1.0),
#  ('a', 'e', 'j', 't', 't', 'u'): ((' ', 'c'), 1.0),
#  (' ', 'c', 'e', 'j', 't', 't', 'u'): (('a',), 1.5),
#  (' ', 'a', 'a', 'e', 'i', 'u'): (('t',), 1.0),
#  (' ', 'a', 'a', 'e', 'i', 'j', 'u'): (('t',), 1.0),
#  (' ', 'a', 'a', 'e', 'i', 't', 'u'): (('j',), 1.0),
#  (' ', 'e', 'i', 't', 't', 'u'): (('j',), 1.0),
#  ('h', 'p'): (('i', 's'), 1.0),
#  ('i', 'p'): (('h', 's'), 1.0),
#  ('h', 'i', 'p'): (('s',), 1.0),
#  ('h', 'p', 's'): (('i',), 1.0),
#  ('i', 'p', 's'): (('h',), 1.0),
#  ('g', 'p'): (('a', 'e', 'n', 'r', 's'), 1.0),
#  ('p', 'r'): (('e',), 1.0),
#  ('g', 'p', 'r'): (('a', 'e', 's'), 1.0),
#  ('g', 'p', 's'): (('a', 'e', 'n', 'r'), 1.0),
#  ('e', 'g', 'p', 's'): (('a', 'n', 'r'), 1.0),
#  ('g', 'p', 'r', 's'): (('a', 'e', 'n'), 1.0),
#  ('e', 'g', 'p'): (('a', 's'), 1.0),
#  ('e', 'n', 'p'): (('a', 's'), 1.0),
#  ('g', 'n', 'p'): (('a', 'e', 'r', 's'), 1.0),
#  ('n', 'p', 'r'): (('a', 'e', 'g', 's'), 1.0),
#  ('e', 'p', 'r'): ((), 1.0),
#  ('e', 'g', 'p', 'r'): (('a', 's'), 1.0),
#  ('g', 'n', 'p', 'r'): (('e',), 1.0),
#  ('n', 'p', 's'): (('a', 'e', 'g', 'r'), 1.0),
#  ('g', 'n', 's'): ((' ', 'a', 'e', 'r'), 1.0),
#  ('p', 's'): (('e', 'r'), 1.0),
#  ('e', 'p', 's'): (('r',), 1.0),
#  ('g', 'n', 'p', 's'): (('a', 'e', 'r'), 1.0),
#  ('n', 'p', 'r', 's'): (('a', 'e', 'g'), 1.0),
#  ('e', 'g', 'n', 'p', 's'): (('a', 'r'), 1.0),
#  ('e', 'g', 'p', 'r', 's'): (('a', 'n'), 1.0),
#  ('e', 'n', 'p', 'r', 's'): (('a', 'g'), 1.0),
#  ...}
